# %% [markdown]
# ## Scraping and Collecting Data

# %%
# !pip -q install transformers
# Out:
#      |████████████████████████████████| 1.3MB 8.4MB/s
#      |████████████████████████████████| 890kB 53.6MB/s
#      |████████████████████████████████| 2.9MB 53.9MB/s
#      |████████████████████████████████| 1.1MB 44.8MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd 

from bs4 import BeautifulSoup
import requests
import csv
import json 


from transformers import MarianTokenizer, MarianMTModel
from typing import List

# %% [markdown]
# ### Creation of a translator, to translate the data that are in French

# %%
model_name = f'Helsinki-NLP/opus-mt-{"fr"}-{"en"}'
model = MarianMTModel.from_pretrained(model_name)               #Loads the MarianMT model
tokenizer = MarianTokenizer.from_pretrained(model_name)

def translate_to_english(text): #Translation function
  if (not text):
    return [text]
  batch = tokenizer.prepare_seq2seq_batch(src_texts=[text])  #Creates word batches for the sequential passing to the model
  generate_model = model.generate(**batch)  
  translation: List[str] = tokenizer.batch_decode(generate_model, skip_special_tokens=True)  #Translation
  return translation
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1133.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=300827685.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=802397.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=778395.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1339166.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=42.0, style=ProgressStyle(description_w…

# %% [markdown]
# ### Creation of Functions that take a URL of the site of a startup and return a small Description line

# %%
def get_Description(url,Translate):
    print(url)

    """
    Return the a small Description of the Startup, which we can find by extracting meta description from urls
    """
    #Send The Request
    try:
          try:
              page = requests.get(url) 
          except ConnectionError:
              page = requests.get(url.replace("https","http"))
      
          #Parse html code
          soup = BeautifulSoup(page.content, 'html.parser')  
          
          
          texts = soup.find("meta", property="og:description")  
          if (texts):      
            text_from_html=texts['content']

          else :
            metas = soup.find_all('meta') 
            meta= ([ meta.attrs['content'] for meta in metas if 'name' in meta.attrs and meta.attrs['name'] == 'description' ])
            if(len(meta)==0):
              return None
            text_from_html=meta[0]

          if(Translate==True):
              text_from_html=translate_to_english(text_from_html)[0] 
              
          return text_from_html  

    except Exception as e: 
          print("Unexpected error:", e)
          return None

# %% [markdown]
# ### Collect Data from lespepitestech.com site

# %% [markdown]
# #### Cookies and headers preparation

# %%
#cookies and headers that the request must contain when sent to the https server
cookies="__cfduid=d831ddcf3d9060346393db0cdfb62618f1602330544; _ga=GA1.2.826854543.1602330545; _fbp=fb.1.1602330545793.1970562287; hubspotutk=c6c0dad3f644023f04005954627b39ff; __smToken=EUHd4DvXWaAdOpYcYFFVjS4F; __smSmartbarShown=Sat%20Oct%2010%202020%2013:49:08%20GMT+0200%20(Central%20European%20Summer%20Time); cookie-agreed=2; __smVID=407637e5549f4681a9305b7ba344acbdd0397db4f22227020022ee44c7b9d66b; SSESSbfe8f364900a8edd3b0626d58c5cb830=tYh81i3x9sFIRbHb9Bgj_GoyCQ5Bvdb4bmf_49qajWA; has_js=1; _gid=GA1.2.163445558.1602615408; __hstc=138838316.c6c0dad3f644023f04005954627b39ff.1602330546137.1602522364578.1602615412109.3; __hssrc=1; __hssc=138838316.6.1602615412109; _gat_UA-58720480-1=1; _gat=1; _dc_gtm_UA-58720480-1=1"
headers="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36*Content-Type: application/x-www-form-urlencoded; charset=UTF-8*Origin: https://lespepitestech.com*Sec-Fetch-Site: same-origin*Sec-Fetch-Mode: cors*Sec-Fetch-Dest: empty*Referer: https://lespepitestech.com/startup-collection/blockchain*Accept-Encoding: gzip, deflate*Accept-Language: en-GB,en-US;q=0.9,en;q=0.8,fr;q=0.7"

#pre-processing of cookies and headers in a dictionnary form 
cookies="{\""+cookies.replace(";","\",\"").replace("=","\":\"") +"\"}"
cookies = json.loads(cookies)

headers="{\""+headers.replace("*","\",\"").replace(": ","\":\"") +"\"}"
headers = json.loads(headers)

# %% [markdown]
# #### Get the url from the page on a one startup

# %%
def get_url(urls):
    url = requests.post(urls, headers=headers,cookies=cookies)
    soup = BeautifulSoup(url.content, 'html.parser')
    s=soup.select_one('div.topWebsite a')
    return str(s['href'])

# %% [markdown]
# #### Get url of startups from a specific page

# %%
def get_startups(urls):
  
    i=k=0

    while(True):
        url = requests.post(urls+"?page="+str(i),headers=headers,cookies=cookies)
        soup = BeautifulSoup(url.content, 'html.parser')
        links=soup.select('a.startup-entry-hitbox')
        if(links):
          for link in links:
                startups.append(link['href'].split("/")[-1])
                startups_urls.append(get_url("https://lespepitestech.com"+link['href']).split("?")[0])
                print(k,link['href'].split("/")[-1])
                k+=1
        else:
            break;

        i+=1

# %%
urls="https://lespepitestech.com/les-ecosystemes-de-la-french-tech"
url = requests.post(urls,headers=headers,cookies=cookies)
soup = BeautifulSoup(url.content, 'html.parser')

startups=[]
startups_urls=[]

links=soup.select('div.card a')
links=[links[i] for i in range(len(links)) if (i%2)==0]
for link in links[1:]:
      
      get_startups("https://lespepitestech.com"+link['href'])

      dataframe = pd.DataFrame(columns=['Name','urlwebsite']) 
      dataframe["Name"]=startups
      dataframe["urlwebsite"]=startups_urls
      dataframe.to_csv("data.csv")
dataframe
# Out:
# 0 medeo
# 1 co-cto
# 2 curvway
# 3 ecosiag
# 4 mylabel
# 5 freelance-stackio
# 6 praxis-web
# 7 ryax-technologies
# 8 angusta
# 9 optimiz-construction
# 10 blueway
# 11 sequoia-factory
# 12 speakingkong-0
# 13 m2
# 14 deligume-0
# 15 swwitch
# 16 watcha-0
# 17 captainconso
# 18 alpissime
# 19 kuso
# 20 skilder
# 21 snowball-esports
# 22 lumeen
# 23 my-little-pressing
# 24 bsoftfr
# 25 mobilax
# 26 ino-vr
# 27 virilite-plus
# 28 smartgarant
# 29 mobilax-academy
# 30 ohmytools
# 31 france-barter-0
# 32 vibris
# 33 caree
# 34 ma-petite-gazette
# 35 kickworker
# 36 harico
# 37 dgtalstory
# 38 neural-decision
# 39 its-acoustique
# 40 parcoor
# 41 sutunam
# 42 upgrade
# 43 tizu
# 44 marketpartscom
# 45 vos-entrainements
# 46 gestia-solidaire
# 47 artoche
# 48 le-bon-gustave
# 49 unipret
# 50 toporder
# 51 braderiepro
# 52 helpsy
# 53 planete-campings
# 54 mission-rgpd
# 55 josepho
# 56 ener-pacte
# 57 cessez-le-feu
# 58 braintogain
# 59 agripousse-0
# 60 petcare-family
# 61 containous
# 62 money-angel
# 63 la-ferme-des-animaux
# 64 homki
# 65 maela
# 66 mon-bel-appart
# 67 choose-your-box
# 68 upowa
# 69 cascade8
# 70 araxxe
# 71 mon-kit-solaire
# 72 travelassistio
# 73 deeplink-medical
# 74 vetbiobank
# 75 alpinov-x
# 76 envisport
# 77 lumapps-0
# 78 laclaree
# 79 iexec
# 80 lynkbooster
# 81 wepeaks
# 82 superpictor
# 83 am-consulting-0
# 84 signitic
# 85 coach2store
# 86 jobypepper
# 87 artinove-0
# 88 vivadata
# 89 jibiscus-boisson-naturelle-la-fleur-dhibiscus
# 90 awezoome
# 91 dood
# 92 mypriceco
# 93 speakingkong
# 94 waster
# 95 winbids
# 96 liberkeys-0
# 97 plusse
# 98 keranova
# 99 nextperience-sas
# 100 visite-360-pro
# 101 neety-0
# 102 digistone
# 103 raiseyourbiz
# 104 asap
# 105 agoora
# 106 neety
# 107 visio-avocats
# 108 crafters-0
# 109 satisfix
# 110 pondy-studio
# 111 le-village-ca-centre-est
# 112 mon-cdi
# 113 samesame
# 114 noshow
# 115 supersoignant
# 116 invisty
# 117 la-totale
# 118 pepitelab
# 119 promy
# 120 wybe-agency
# 121 influcom
# 122 lesbonstech
# 123 legal-booster
# 124 crafters
# 125 businove
# 126 semji
# 127 inasoft
# 128 klevr
# 129 mygladys
# 130 lespace-digital-leled
# 131 kickbanking
# 132 le-monde-immo
# 133 quelle-sera-ma-retraite
# 134 tenor-edi-services
# 135 business-en-ligneio
# 136 malika
# 137 antidot
# 138 sagessesante
# 139 rockingshare
# 140 agripousse
# 141 calchemise
# 142 heatskin-bpsystemes
# 143 chiche
# 144 crg-quality-consulting
# 145 ido-data
# 146 sunbren
# 147 talengers
# 148 hume
# 149 eludice
# 150 planmytrip
# 151 koki-software
# 152 paylcd
# 153 independantio
# 154 its-taraprint
# 155 elium
# 156 1kubator
# 157 v-pour-verdict
# 158 hif-alias-yatu
# 159 e-ophtalmo
# 160 ineat-group
# 161 orok
# 162 stanley-robotics
# 163 contentside
# 164 magnisense
# 165 entrup-0
# 166 ucolis
# 167 zest
# 168 hoomz
# 169 piwio-bureau-detude-iot-objets-connectes-data-science-electronique
# 170 mobifactory
# 171 e-attract
# 172 cadeau-maestro
# 173 duflaircom
# 174 deligume
# 175 formalisdc
# 176 x
# 177 mihotel
# 178 digireward
# 179 imageseo
# 180 finnocar
# 181 cosmo-tech
# 182 mon-site-webio
# 183 kioskemploi
# 184 cv-en-ligneio
# 185 georges-le-robot-comptable
# 186 roads4you
# 187 lyko
# 188 alter-way
# 189 smartphone-id
# 190 aleph-networks
# 191 kumulus-vape
# 192 finkey
# 193 algorys
# 194 eficia
# 195 energisme
# 196 et-voila-ca-marche
# 197 animalost
# 198 mylight-systems
# 199 zenika
# 200 cpecf
# 201 nightswappinng
# 202 elise-technologies
# 203 linkvalue
# 204 clem
# 205 restons-en-vigne
# 206 novadiscovery
# 207 greentraders
# 208 menajtoi
# 209 vue-des-tribunes
# 210 louerunepiscine
# 211 care-eat
# 212 proxival
# 213 bcm-energy
# 214 shamballa
# 215 wikit
# 216 attestation-legale
# 217 nouveal-e-sante
# 218 2c2l-sas
# 219 legal-pilot
# 220 tankyou
# 221 yurplan
# 222 winly
# 223 hina-tea
# 224 redfox-finance-0
# 225 diginamic
# 226 kobalt
# 227 welcome
# 228 sondeve
# 229 cliqeo
# 230 instantassur
# 231 mendity
# 232 cap-sud
# 233 paablo
# 234 smash
# 235 teepy-job
# 236 mestravauxcom
# 237 freecity
# 238 finalgo
# 239 payxpert
# 240 enoptea
# 241 minis-moi
# 242 flexjob
# 243 kickandboost
# 244 safetyn
# 245 miuros
# 246 wuha
# 247 klappio
# 248 buyer
# 249 sante-net
# 250 elcia
# 251 kosmos
# 252 skyzen
# 253 myexpatus
# 254 zoom-espagne-zoom-cuba
# 255 meersens
# 256 innoradiant
# 257 izycardio
# 258 la-centrale-du-sport
# 259 wedoogift
# 260 studenjoy
# 261 le-bon-controle-urssaf
# 262 copark
# 263 my-digital-buildings
# 264 piwii-soutenons-les-commercants-de-quartier-livraison-de-produits
# 265 consultoo
# 266 zcost-management
# 267 prismo
# 268 addon-acs
# 269 mgstudiodesign
# 270 biin
# 271 dwyt-watch
# 272 agicap
# 273 ouivallee
# 274 okeenea
# 275 jem
# 276 myowlmarket
# 277 obiz-concept
# 278 webradiostore
# 279 easycoopt
# 280 united-motion-ideas
# 281 barratio
# 282 clicfacture
# 283 copromatic
# 284 artinove
# 285 grow
# 286 all-one
# 287 huby
# 288 mudita
# 289 hyperbolyk
# 290 boot-start
# 291 2emotion
# 292 follow-patient
# 293 weeefund
# 294 holdies
# 295 1d-lab
# 296 eazylang
# 297 museopic
# 298 housquarecom
# 299 denicheur-de-vins
# 300 vinovae
# 301 mereos
# 302 clictill
# 303 fundy
# 304 slab-luxe-system
# 305 prototypo
# 306 social-bike-club
# 307 swisspay
# 308 erbol
# 309 dawex
# 310 smokingfr
# 311 cheapshipbiz
# 312 stopilo
# 313 avec-plaisir
# 314 mathplace
# 315 ulex-innovative-systems
# 316 weflat
# 317 cyclofix-0
# 318 lucky-cart
# 319 pourlapetitehistoire
# 320 mazen
# 321 arskan
# 322 magnify-me
# 323 very
# 324 uppersafe
# 325 bejoe
# 326 hellocasa
# 327 my-expat
# 328 vericampus
# 329 cybeel
# 330 hellocse
# 331 datagalaxy
# 332 algosecure
# 333 teach
# 334 innovisite
# 335 hexadrone-sas
# 336 pomelawfr
# 337 gamebuino
# 338 meteojob
# 339 rium
# 340 webmy3d
# 341 inditicket
# 342 editions-la-belle-idee
# 343 linkbynet
# 344 welkom
# 345 wair
# 346 resolving
# 347 dring-novin
# 348 ubiant
# 349 wizyfab
# 350 hease-robotics
# 351 reputation-vip
# 352 datagenius
# 353 la-capsule-academy
# 354 forcity
# 355 rtone
# 356 jaguar-network
# 357 smart-traffik-evoke
# 358 miraxess
# 359 sportsconnect
# 360 acs-biotech
# 361 entrup
# 362 fortify
# 363 tilkee
# 364 parkmatch
# 365 clim8
# 366 hoomano
# 367 twinswheel
# 368 skilvioo
# 369 everblix
# 370 incwo
# 371 gac-technology
# 372 ellemots
# 373 commanders-act
# 374 myartisrich
# 375 swabbl-1
# 376 econocom
# 377 eolys-beaute
# 378 beebryte
# 379 formalearning
# 380 nelio
# 381 hub-grade
# 382 vyneo
# 383 jvf
# 384 jobculturefr
# 385 kin-calendar
# 386 jesorsenville
# 387 swikly
# 388 cybersas
# 389 innovation-digitale
# 390 holimeet
# 391 megacitizcom
# 392 apps-panel
# 393 linkoo-technologies
# 394 en-mode
# 395 bealder-analytics
# 396 x3d-group
# 397 workswin
# 398 wizaplace
# 399 signes-et-formations
# 400 made-share
# 401 nuabee
# 402 squadata
# 403 hubware
# 404 e-recycle
# 405 vg-sens-0
# 406 codeffekt
# 407 biboard
# 408 oe
# 409 woozjob
# 410 holimetrix
# 411 bemysport
# 412 la-centrale-du-sport-0
# 413 avis-de-runners
# 414 la-boutonniere
# 415 degustco
# 416 dougs
# 417 gestionclub
# 418 adventure05
# 419 seety
# 420 trainme
# 421 roxwhale
# 422 code-adn
# 423 mailclark
# 424 3dshop
# 425 strime
# 426 holi
# 427 telemedecine-360
# 428 mytutorabroad
# 429 mamedecinefr
# 430 lili-smart
# 431 swabbl-0
# 432 virdys
# 433 carsecure
# 434 higheredmecom
# 435 interactive-wall
# 436 vesper
# 437 commercitecom
# 438 heyway
# 439 bob-depannage
# 440 longonya
# 441 mr-gustave
# 442 de-rigueur
# 443 pretikfr
# 444 charging-phone
# 445 energiency
# 446 ogga
# 447 bluebe
# 448 affeeniteam
# 449 owl
# 450 free-your-inbox
# 451 cognik
# 452 protournoi
# 453 ovh
# 454 bidul
# 455 canalmatch
# 456 lagazel
# 457 la-smartphonerie
# 458 nettelo
# 459 cosmo-company
# 460 whisperies-0
# 461 blooweels
# 462 ourniaco
# 463 umalis-connect
# 464 doz
# 465 synthes3d
# 466 skill
# 467 peekroom
# 468 witekio
# 469 kiss-launcher
# 470 vousformez
# 471 idyze
# 472 linksoft
# 473 rep-advisor
# 474 boostinlyon
# 475 ifeedforu
# 476 kelips
# 477 casalink
# 478 neolid
# 479 my-angel
# 480 monclubbusinesscom
# 481 bpeek
# 482 axeleo
# 483 coffret-du-gourmet
# 484 geolid
# 485 digischool
# 486 kobone
# 487 jellynote
# 488 mapado
# 489 jobbons
# 490 ecocityz
# 491 rollkers-pre-lancement
# 492 nightswapping
# 493 cityzen-sciences
# 494 votre-numero-de-serie
# 495 kimbox
# 496 fasola
# 497 monpotagercom
# 0 asking-franklin
# 1 smartbottle
# 2 obvy
# 3 ctotech
# 4 numa-health-international
# 5 vitirover-sas
# 6 exascale
# 7 sortvoices
# 8 meet-business-students
# 9 hellogova
# 10 iyoo
# 11 nomads-surfing
# 12 sportnovae
# 13 amiimo
# 14 alogia
# 15 webmaniac
# 16 yooji
# 17 millenia
# 18 maloric
# 19 groupe-mobility
# 20 handiroad
# 21 iziweb33
# 22 troov
# 23 irep
# 24 localsquare
# 25 formatch
# 26 technique-solaire
# 27 apivideo
# 28 dynamicscreen
# 29 kyango
# 30 gloo
# 31 wavoff
# 32 hortusbox
# 33 inheart
# 34 coloc-and-you
# 35 multimedia-solutions
# 36 we-go-greenr
# 37 capitaine-study
# 38 miap
# 39 blue-valet
# 40 lafleur-toiture
# 41 dgtalstory
# 42 darwin-nutrition
# 43 petit-brunch
# 44 josepho
# 45 agence-netlinking
# 46 formation-seo-bordeaux
# 47 opquast
# 48 homki
# 49 freemiumplay
# 50 aelis-farma
# 51 market-solutions
# 52 mon-kit-solaire
# 53 ouirestaurationfr
# 54 partners-finances
# 55 crowdmapio
# 56 ideal-groupe
# 57 leakswatcher-par-littlebluefoxio
# 58 petite-marelle
# 59 fineheart
# 60 comerso
# 61 easy-live
# 62 journee-de-chasse
# 63 meshroomvr
# 64 realitytech
# 65 lnc-therapeutics
# 66 yescapa
# 67 iqspot
# 68 paylead
# 69 sommit
# 70 whatzhat-design-agency
# 71 keyclic
# 72 littlebluefoxio
# 73 immo-data
# 74 wazzar
# 75 elwin
# 76 touch-sell
# 77 fly-sourcing
# 78 planilog
# 79 wer-service
# 80 topa
# 81 spationautefr
# 82 goyalab
# 83 kymee
# 84 drone-geomodeling
# 85 treefrog-therapeutics
# 86 inblocks
# 87 moja-audio
# 88 homebot
# 89 lucas-ollivier
# 90 myadsart
# 91 pim-0
# 92 libon
# 93 loisirs-encheres
# 94 instaboss
# 95 oncrawl
# 96 bientot-chez-soi
# 97 chandago
# 98 popgame-0
# 99 moon-harbour
# 100 french-tooth
# 101 stockly
# 102 neeva
# 103 bluebakelite
# 104 hypnoledge
# 105 best-itinerary
# 106 welyb
# 107 eficia
# 108 first2trade
# 109 yapero-livraison-dalcool
# 110 zenika
# 111 qucit
# 112 carbon-waters
# 113 base
# 114 embaucheur
# 115 blapote
# 116 deal2drive
# 117 marebiz
# 118 pagescreen
# 119 gossy
# 120 la-fabrique-juridique
# 121 cliqeo
# 122 artist-live
# 123 summerize
# 124 ma-petite-jardinerie
# 125 spationaute
# 126 air-marine
# 127 boaton
# 128 scilight
# 129 sas-ing
# 130 factoryz
# 131 comiteo
# 132 azendoo
# 133 myshop-e
# 134 hypview
# 135 lhuile-barbe
# 136 cabazen
# 137 splity
# 138 qik-objects
# 139 poupou-0
# 140 juridip
# 141 teneo
# 142 nighthawks-cocktails
# 143 startmystory
# 144 yoope
# 145 expateo
# 146 mediapublicitaire
# 147 we-prod-local
# 148 message-window
# 149 ancodea
# 150 oboem
# 151 kantree
# 152 immo-pop
# 153 groupe-cartegie-lead-wayr
# 154 cp3i
# 155 bougetonkid
# 156 fygostudio
# 157 clay-vr
# 158 deliverbag
# 159 alkion-bioinnovations
# 160 opinion-system
# 161 quietudeio
# 162 liweo-sas
# 163 fretly
# 164 jul-et-fil
# 165 goodbail
# 166 parlonspo
# 167 grandsvins-privescom
# 168 syncpad
# 169 witivio
# 170 horse-innovation-talks
# 171 cestdanslecoin
# 172 jaime-mes-plantes
# 173 cinquieme-de-couv
# 174 mumbo-jumbo
# 175 immersion
# 176 guide-des-chemins
# 177 bmia-0
# 178 intento
# 179 9h05
# 180 mapotempo
# 181 melpix
# 182 vr-bnb
# 183 les-blouses-blanches
# 184 help-and-home
# 185 invivox
# 186 knock
# 187 popvox
# 188 epatient-digital-medias
# 189 nutreatif
# 190 legal-vision
# 191 la-malle-aux-fripes
# 192 sunday-0
# 193 bestrade
# 194 gazelle-tech
# 195 meteojob
# 196 groupe-cd-media
# 197 linkbynet
# 198 bylithium
# 199 simforhealth-interaction-healthcare
# 200 nutrikeo-consulting
# 201 persistant-studios
# 202 insiteo
# 203 wiidii
# 204 popsite
# 205 newmips
# 206 wondragency
# 207 nomadeec-exelus
# 208 assurancestech
# 209 asknrelax
# 210 jechange
# 211 vitavinum
# 212 wing
# 213 les-personnalisablescom
# 214 picturehit
# 215 rcom-media-support
# 216 emsproto
# 217 surveyboardcc
# 218 jestockecom
# 219 oandb
# 220 dataprint-telecom
# 221 jvf
# 222 pollroll
# 223 art-graphique-patrimoine
# 224 proxgroup
# 225 10h11
# 226 kweezine
# 227 je-pilote
# 228 vertical-system-inc
# 229 urself
# 230 ouipharmafr
# 231 artphotolimited
# 232 kelvente
# 233 map-your-stories
# 234 arkade
# 235 sos-reputation
# 236 hopen-project
# 237 nabuco
# 238 vertical-system
# 239 tips-le-bouche-oreille-20
# 240 datarespect-magush
# 241 fitmakers
# 242 check-kit
# 243 nfc-i
# 244 vitalbase
# 245 buzziness
# 246 wawee
# 247 calldoor
# 248 co-riderfr
# 249 purefood
# 250 fitmyrun
# 251 forecast
# 252 uxer
# 253 widdim
# 254 cforgood
# 255 wecomfrom
# 256 gablys
# 257 aguila-technologies
# 258 bob-depannage
# 259 btobag
# 260 demooz
# 261 adresses-gourmandes
# 262 edevice
# 263 voxeet
# 264 wiidii-0
# 265 ekylibre
# 266 ecoclicot
# 267 art-lover-place
# 268 weenove
# 269 tricy
# 270 caramaps
# 271 kapp10
# 272 kidolia
# 273 brainify
# 274 ubimmo
# 275 airvy
# 276 swap-and-surf
# 277 ezakus
# 278 mib-clean
# 279 rewind
# 280 jamshake
# 281 switcharound
# 282 news-republic
# 283 apps-milesr
# 284 tamashare
# 285 samboat
# 286 fidme
# 287 tehtri-security
# 288 rocketfid
# 289 jaidemaville
# 290 blitzr
# 291 ecopresto
# 292 tawa
# 293 winewoo
# 0 olkos
# 1 ogoxe
# 2 webmaniac
# 3 murmuration-sas-flockeocom
# 4 know-minut
# 5 tamplo
# 6 trynbuy
# 7 le-gout-du-coq
# 8 ascendance-flight-technologies
# 9 profil-public
# 10 wemet
# 11 kestya
# 12 fimaloc
# 13 mypangee
# 14 album-family
# 15 meri-digital
# 16 izidore
# 17 uwinloc
# 18 linguifamily
# 19 dieu-des-pronos
# 20 kaliz
# 21 axokey
# 22 urbidesk
# 23 pose-ton-sac
# 24 axineuf
# 25 homki
# 26 comenge
# 27 iminnov
# 28 authentic-material
# 29 market-solutions
# 30 louis
# 31 cell-easy
# 32 linkweb-0
# 33 ibat
# 34 karlia
# 35 box-everywhere
# 36 fullsave
# 37 france-tombale
# 38 prooftag
# 39 medylink
# 40 prodi-art
# 41 hypnia
# 42 bloomup
# 43 nisivita
# 44 bonjour-senior
# 45 immo-solo
# 46 ermine
# 47 clood
# 48 kpulse
# 49 jevendsmaparcellecom
# 50 coproactive
# 51 mecavin
# 52 immofix
# 53 floodlight
# 54 poolcare
# 55 la-mandrette
# 56 startup-me
# 57 dev-id
# 58 schoolmouv
# 59 tesalys
# 60 merciyanis
# 61 melting-films
# 62 voxtech-gs-vote
# 63 cortex-informatique
# 64 comparateur-promoteur
# 65 hey-alex
# 66 naio-technologies
# 67 predify
# 68 sideklick
# 69 kaduceo
# 70 la-fabrique-innovations
# 71 boby
# 72 le-cameleon-dine
# 73 rubix-si
# 74 x
# 75 printoclock
# 76 chapngo
# 77 winstate
# 78 cyboolo
# 79 ocenter
# 80 travelmedicard
# 81 la-boitapero
# 82 speaknate
# 83 mytriplan
# 84 getfluencecom
# 85 quiditmiam
# 86 cronobo
# 87 geotrend
# 88 pangee
# 89 mon-alternance
# 90 oklyn
# 91 oworkers
# 92 munki
# 93 ezlearn-conseil
# 94 novatopo
# 95 green
# 96 bleexo
# 97 maxidays
# 98 edebex
# 99 appetia
# 100 adopte-ma-tomate
# 101 made-reve
# 102 castagne
# 103 powertech-systems
# 104 enobraq
# 105 h2i
# 106 wellstone
# 107 estimancy
# 108 stoby
# 109 edmon
# 110 previsionio
# 111 ovalie-tech
# 112 minitopo
# 113 mbscott
# 114 mange-quoi
# 115 creavilia
# 116 watch-eat
# 117 corilla
# 118 consocouches
# 119 wildesk
# 120 mediation-immo
# 121 safetyn
# 122 caseinjob
# 123 permagrowing
# 124 immo-quartier
# 125 silex
# 126 altospam
# 127 youscribe
# 128 onestock
# 129 vraimentpro
# 130 courriertech
# 131 axible
# 132 diodon-drone-technology
# 133 kosmos
# 134 micromobile
# 135 sweepers
# 136 snappress
# 137 epicerie-de-nuit
# 138 myexpatus
# 139 untienots
# 140 oh-la-vache
# 141 equivisio
# 142 mandea
# 143 acapela-group
# 144 smyler
# 145 labstorant-0
# 146 labstorant
# 147 agence-juridique
# 148 savez-vous-planter-chez-nous
# 149 shippingbo
# 150 my-flying-box
# 151 zcost-management
# 152 kagilum
# 153 botdesign
# 154 studio-hapax
# 155 belami
# 156 syscobat
# 157 lonama
# 158 bioleads
# 159 diabolocom
# 160 emprunte-mon-toutou
# 161 authot
# 162 mylangoo
# 163 karavaneserail
# 164 azuneed-rh
# 165 eurecia
# 166 mimbus
# 167 dolidemat
# 168 izidore-meubles-doccasion
# 169 appstud
# 170 spart
# 171 axonaut
# 172 bioexpert-network
# 173 jlogiciels
# 174 phonefix
# 175 institut-des-medias-avances
# 176 staffman
# 177 pixi
# 178 swish-live
# 179 wefarmup
# 180 delair
# 181 vendreaunpromoteurcom
# 182 anakeen
# 183 band-band
# 184 catspad
# 185 amarenco
# 186 accelad
# 187 ra
# 188 emindhub
# 189 notresante
# 190 opendecide
# 191 algyou
# 192 liberty-rider
# 193 airborne-concept
# 194 cencial-group
# 195 mycloclo
# 196 tech-corner
# 197 terroiko
# 198 aubaine
# 199 jobirl-lorientation-real-life
# 200 skimflow
# 201 intent-technologies
# 202 connit
# 203 wepolly
# 204 flipr
# 205 hop-crm
# 206 visiopm
# 207 comm1possible
# 208 maestro-corporation
# 209 3dvarius
# 210 tech-smile
# 211 inodex-3d
# 212 eldotravo
# 213 treevea
# 214 bubbleflat
# 215 betters-rift
# 216 ludilabel
# 217 xtraball
# 218 44-screens
# 219 pole-star
# 220 insiteo
# 221 taleez
# 222 donecle
# 223 openairlines
# 224 telegrafik
# 225 nanolike
# 226 ehtech
# 227 nowave
# 228 syntony-gnss
# 229 rocket-0
# 230 emotion-tech
# 231 covirtua
# 232 pilot-things
# 233 citizenfarm
# 234 assurancestech
# 235 prismeai
# 236 telequid
# 237 earthcube
# 238 livebercom
# 239 valqualim
# 240 linscriptioncom
# 241 brikawood
# 242 youprix
# 243 private-innovation
# 244 oandb
# 245 distrix
# 246 jvf
# 247 trf-retail
# 248 hopler
# 249 easymile
# 250 nanomade
# 251 itrust
# 252 airvada
# 253 cellys
# 254 brennus-analytics
# 255 facturenet
# 256 politizr
# 257 hubware
# 258 datapublic
# 259 myteleworker
# 260 iterop
# 261 start-track
# 262 la-belle-le-barbu
# 263 capturs
# 264 workout-france
# 265 mountnpass
# 266 coovia
# 267 rocket
# 268 paarly
# 269 flightwatching
# 270 ubleam
# 271 kissmyshoe
# 272 adveez
# 273 ubigreen
# 274 demooz
# 275 cenareo
# 276 skiller
# 277 france-pari
# 278 fittingbox
# 279 el-needo
# 280 ski-discount-france
# 281 netexplorer
# 282 willty
# 283 ovh
# 284 bleemeo
# 285 unooc
# 286 vivent
# 287 economics-games
# 288 nirby
# 289 french-app
# 290 placeboard
# 291 sunday
# 292 drivoo
# 293 myfeelback
# 294 noova
# 295 parkisseo
# 296 boxmyjob
# 297 globewhere
# 298 xfield-paintball-video-game
# 299 prenom-de-bebe-2
# 300 keysmagnet
# 301 printshot
# 302 sigfox
# 303 tonpsy-psychologues-par-webcam
# 304 morning-payname
# 305 toolmapp
# 306 saumo
# 0 azuvia
# 1 udicat
# 2 happy-funky-family
# 3 birds-change
# 4 doinsport
# 5 fintel
# 6 teeneo
# 7 olythe
# 8 solable
# 9 smartpush
# 10 quickms
# 11 hello-my-cake
# 12 alexandre-m-frenchy
# 13 abc-digital-touch-io
# 14 innovacases-sas
# 15 rbmg-consulting
# 16 obratori
# 17 waggon
# 18 sunleavs
# 19 virtuafire
# 20 marklix-0
# 21 sponsokit
# 22 connecteque
# 23 galaxy-seo
# 24 froggylab
# 25 marklix
# 26 octarina-0
# 27 digital-paca
# 28 modules-prestashop
# 29 my-food-story-0
# 30 pixxle
# 31 legalcity
# 32 stoquemarket
# 33 sellsign-0
# 34 dailywash
# 35 c4diagnostics
# 36 unique-heritage-media
# 37 letsignit-0
# 38 homki
# 39 gravipack
# 40 articlaw
# 41 payrequest
# 42 wall-traders
# 43 plateo
# 44 proviridis
# 45 partners-finances
# 46 optimum-automotive
# 47 avis-verifies-net-reviews
# 48 les-vergers-du-sud
# 49 subclic
# 50 sportall
# 51 rofim
# 52 premaccess
# 53 diamidex
# 54 onatera
# 55 dimojo
# 56 nextperience-sas
# 57 tchek
# 58 visite-360-pro
# 59 lepriximmo
# 60 abc-coach-sportif-aix-en-provence
# 61 open-lowcode
# 62 happywiz
# 63 kampn
# 64 tuyoo
# 65 walter-learning
# 66 market-hours
# 67 ilab-mister-compta
# 68 evalbox
# 69 freshdev
# 70 bigboat
# 71 mysofie
# 72 alices-world
# 73 atraki
# 74 e2vr-e-commerce-virtual-reality
# 75 assur-mutuelle
# 76 anapix-medical
# 77 bruno
# 78 webikeo
# 79 oxyne
# 80 ombrea
# 81 wisetax
# 82 web-wizards
# 83 dev-id
# 84 electric-55-charging
# 85 easy-partner
# 86 bienpreter
# 87 touche-pas-mon-artisan
# 88 mon-autoentreprisefr
# 89 aia
# 90 prohacktive
# 91 comparateur-hopenergiecom
# 92 mamaz-social-food
# 93 tipikk
# 94 theweb3
# 95 maison-2-familles
# 96 covfefecorner
# 97 mywoodream
# 98 socios
# 99 kyklos-gaming
# 100 crosscall
# 101 saileazy
# 102 volta-medical
# 103 crocos-go-digital
# 104 dualsun
# 105 metals-industry
# 106 metals-industry-0
# 107 juripredis
# 108 clean-city
# 109 smartwiz
# 110 gamertech
# 111 aglaiaco
# 112 alter-way
# 113 gamned
# 114 icome
# 115 aspirotop
# 116 holingo
# 117 nanoz-0
# 118 voyage-prive
# 119 yapero-livraison-dalcool
# 120 cpecf
# 121 mailinblack-anti-spam
# 122 calinda-software
# 123 sport-decouverte
# 124 mini-green-power
# 125 aperitivbox
# 126 smart-futures
# 127 macomptabilite
# 128 easilys
# 129 albert-learning
# 130 hysilabs
# 131 lookap
# 132 1000applis
# 133 jveuxdusoleil
# 134 anytime
# 135 minutpass
# 136 mongrillon
# 137 algonomia
# 138 archireality
# 139 minimall
# 140 cliqeo
# 141 locdelinge
# 142 haliodx
# 143 gojob
# 144 zchocolat
# 145 cpe-associes
# 146 smartear
# 147 hdsn
# 148 altadeva
# 149 advanced-intelligent-mechatronics
# 150 exolis
# 151 geo-sentinel
# 152 bio-pool-tech
# 153 lumiin
# 154 myexpatus
# 155 0w1-audio
# 156 walkoo
# 157 wintual
# 158 hortime
# 159 smsmode
# 160 icon
# 161 tynkle
# 162 watch-and-give
# 163 balis
# 164 meilleurartisancom
# 165 imparato
# 166 equipement-randonnee
# 167 mon-bonus-malus
# 168 exalt3d
# 169 graphcomment
# 170 mturcanpro-consultant-seo-marseille
# 171 clienteo
# 172 greencityzen
# 173 crosslux
# 174 viaxoft
# 175 poste-en-anglais
# 176 beforgocom
# 177 care-my-car
# 178 mood-messenger
# 179 chilowe
# 180 ween
# 181 onsenvol
# 182 zelasticket
# 183 ruecentrale
# 184 payrfect
# 185 develink
# 186 smart-tribune
# 187 domaine-legalcom
# 188 chaze
# 189 takoma
# 190 creaboxdigitale
# 191 g2c-informatique
# 192 carteltech
# 193 g2c-ingenierie
# 194 natural-solutions
# 195 buzzlike
# 196 lola-sonora-labs
# 197 buyco
# 198 click-dive
# 199 cap-compta
# 200 a6telecom
# 201 customer-labs
# 202 genesink
# 203 recitsdumondefr
# 204 equiswap
# 205 xpertio
# 206 spicetronic
# 207 meteojob
# 208 ontracksco
# 209 babel-community
# 210 wineven
# 211 ondilo
# 212 aroma-therapeutics
# 213 novathings
# 214 ironova
# 215 perspectives
# 216 bookmyhelo
# 217 jaguar-network
# 218 mafiscalitecom
# 219 thinkgo
# 220 fin-track
# 221 siweb
# 222 pixxim
# 223 prescrit
# 224 swap
# 225 fenotek
# 226 cliponlike-productions
# 227 iprotego
# 228 steerfox
# 229 hupp
# 230 citydrive
# 231 smart-cycle
# 232 axyn-robotique
# 233 kalyzee
# 234 space-designer-3d
# 235 recsi-group
# 236 totem-mobi
# 237 emana
# 238 light4events
# 239 ardemis-partners
# 240 physio-extrem
# 241 itec-services
# 242 stokkly
# 243 bb-d
# 244 yesouijob
# 245 allogarage
# 246 easyverif
# 247 ubiq
# 248 media-rewards
# 249 challengr
# 250 plezi
# 251 keeex
# 252 loomup
# 253 social-maker
# 254 kazaram
# 255 experience-privee
# 256 atadispo
# 257 no
# 258 phonomatik-lab
# 259 wizwedge
# 260 zei-accelerateur-decologie
# 261 gyroscope
# 262 home-connected
# 263 bookingsync
# 264 applywith-par-tekoway
# 265 selerys
# 266 octoperf
# 267 sociallymap
# 268 market-invaders
# 269 cmonsite
# 270 photographie-direct
# 271 letsignit
# 272 livre-mois
# 273 terradona
# 274 evolix
# 275 opsideco
# 276 inspectimmofr
# 277 ski-discount-france
# 278 xtim-bionic-bird
# 279 neotion
# 280 ikimo9
# 281 echy
# 282 imxpad-sas
# 283 eukles-solutions
# 284 oenojet
# 285 miwili
# 286 popup-house
# 287 wetube
# 288 synthes3d
# 289 funddler
# 290 yuzu
# 291 skinkin
# 292 crmble
# 293 io-software
# 294 3drudder
# 295 kaporal-connecting-jean-pre-reservation
# 296 flooz
# 0 kajou
# 1 retail-shake
# 2 whispeakio
# 3 webmaniac
# 4 amalia
# 5 hucom
# 6 scankey
# 7 flightdelay
# 8 airpote
# 9 1kubator-lille
# 10 syllabus-media
# 11 dizy
# 12 monitorize
# 13 unsold
# 14 spationauteio-agence-web-lille
# 15 premier-cap-0
# 16 logology
# 17 flock-you-vetements-personnalises
# 18 itandi
# 19 premier-cap
# 20 sos-bilan
# 21 le-meilleur-pronostiqueur
# 22 all4affiliatescom
# 23 stadihome
# 24 les-blobs
# 25 betm
# 26 hop3team
# 27 heatzy
# 28 mon-kit-solaire
# 29 efficience-it
# 30 lotacloud
# 31 partners-finances
# 32 parkki-0
# 33 centre-europeen-de-formation
# 34 datacadabra
# 35 gecco
# 36 premaccess
# 37 sublissime
# 38 vdkg-huissier-arras
# 39 visite-360-pro
# 40 joe-rnalist
# 41 playgroond
# 42 orientoi
# 43 holiable
# 44 paprwork
# 45 tripori
# 46 videas
# 47 open-cooking
# 48 doctowait
# 49 titiranol
# 50 kurrikulam
# 51 reactevent
# 52 autodidaxy
# 53 da-business-development-cote-ouest
# 54 kylii-kids
# 55 babyclo
# 56 pliveo
# 57 bluemanoid
# 58 testsecurite
# 59 hellogoodbail
# 60 exotec-solutions
# 61 booper
# 62 lattice-medical
# 63 ecolog-innovation
# 64 ineat-group
# 65 makerspot
# 66 wesecure
# 67 reussirimmo
# 68 travel-you
# 69 crypto-sous
# 70 e-zyvec
# 71 emplio
# 72 alter-way
# 73 info4s
# 74 clicdata
# 75 work-around-world
# 76 praestoo
# 77 zenika
# 78 musicalink
# 79 feedier
# 80 tryfit
# 81 utocat
# 82 linkvalue
# 83 kozikaza
# 84 5e-acte
# 85 sicara
# 86 sharework
# 87 karnott
# 88 cozy-air
# 89 businessline
# 90 onejitsu
# 91 beefid
# 92 oko-0
# 93 le-wagon-lille
# 94 foxfinder
# 95 infimed
# 96 touchetacom
# 97 ploc
# 98 tankyou
# 99 visite-virtuelle360fr
# 100 airstick
# 101 cabinet-df-associes
# 102 my-bio-time
# 103 sistina
# 104 junior-makers-place
# 105 cliqeo
# 106 obvioos
# 107 so-sample
# 108 akuiteo
# 109 patronimcom
# 110 tabuleo
# 111 ava-ag
# 112 immotio
# 113 payboost
# 114 parkki
# 115 disruptual
# 116 whoop-kids
# 117 tesla-4u-0
# 118 spogeo
# 119 bonjour-barcelone
# 120 marketing-1by1
# 121 wedoogift
# 122 oncle-bacchus
# 123 botners
# 124 made-local
# 125 mon-petit-coin-vert
# 126 legipermis
# 127 wegravit
# 128 elamp
# 129 anybuddy
# 130 kinov
# 131 cryptalert
# 132 squaremx
# 133 groix-online
# 134 stimshop
# 135 quesp
# 136 comptoir-des-millesimes
# 137 mytroopers
# 138 inwall
# 139 platofjour
# 140 my-lead-corner
# 141 lille-city-shop
# 142 mapreuve
# 143 chen
# 144 eatizzycom
# 145 potion-social
# 146 trackit
# 147 mercited
# 148 passive-records
# 149 holyvent
# 150 seateezy
# 151 jackmail
# 152 wannabeer
# 153 mushin
# 154 clic2buy
# 155 isaert-developpement-et-ingenierie
# 156 hellocasa
# 157 delaplacepro
# 158 moffi
# 159 popvox
# 160 energic
# 161 sensefuel
# 162 agree
# 163 syndic-one
# 164 argo
# 165 meteojob
# 166 oraclys
# 167 stereograph
# 168 homido
# 169 e-medservice
# 170 jagger-lewis
# 171 gyromotion
# 172 jooxter
# 173 forcity
# 174 mapwize
# 175 embisphere
# 176 axbx
# 177 praedic
# 178 la-mobilery
# 179 xee
# 180 lysphere
# 181 enki
# 182 gaspardalice
# 183 commanders-act
# 184 les-tilleulscoop
# 185 elwing-boards
# 186 muvzi
# 187 japet-medical-devices
# 188 largerio
# 189 hozone
# 190 fabriks
# 191 insitaction
# 192 phoceis
# 193 yumii-0
# 194 fidelisa
# 195 stocketmoi
# 196 my-box-corner
# 197 shotgun-covoit
# 198 ruok
# 199 ecotechnics
# 200 digital-collab
# 201 kinomap
# 202 smart-pap
# 203 concierge
# 204 otonohm
# 205 scarit
# 206 equisense
# 207 cutii
# 208 fous-de-trucks
# 209 dagoma
# 210 eagolf
# 211 returnmykeycom
# 212 alerteo
# 213 valoro-fundraising
# 214 miam-miam-connection
# 215 pepper-buy
# 216 pingflow
# 217 taikoon
# 218 resalib-lamedecinedoucecom
# 219 effipilot
# 220 bob-depannage
# 221 simplifield
# 222 openio
# 223 sensiolabs
# 224 ovh
# 225 adrenalivre
# 226 weenat
# 227 metod
# 228 label-blanc
# 229 umalis-connect
# 230 tutti-flirty
# 231 legendareit
# 232 valoro-path
# 233 permettez-moi-de-construire
# 234 tipimail
# 235 deconov
# 236 spamenmoins
# 237 yuzu
# 238 real-time-analytics
# 239 espaciel
# 240 izyloccom
# 241 frizbiz
# 242 holusion
# 243 le-comparateur-assurance
# 244 ninchanese
# 245 giroptic
# 246 labonneoffre
# 247 dividom
# 248 mobile-angelo
# 249 ouistock
# 250 nuukik
# 251 buzzcar
# 252 ecotaco
# 253 mon-itinerant
# 254 interactive-4d
# 255 advanilla
# 256 commentseruiner
# 257 mazeberry
# 258 jobijoba
# 259 click-and-walk
# 260 colisweb
# 261 pumpkin
# 0 darlow
# 1 essteem
# 2 tarform
# 3 ab-tasty
# 4 contentsquare
# 5 gutenberg-technology
# 6 octoly
# 7 try-world
# 8 upflex
# 9 amazing-transcript
# 10 visual-subtitling
# 11 video-transcription-services
# 12 click-translation
# 13 stonly
# 14 academic-translation-services
# 15 vanan-captioning-0
# 16 wibbitz
# 17 uppler
# 18 ds-digital
# 19 vanan-captioning
# 20 upslide
# 21 wiztopic
# 22 businove
# 23 gingalab
# 24 pop-masters
# 25 wezenitcom
# 26 processout
# 27 jop
# 28 element
# 29 commoddt
# 30 blasty
# 31 qucit
# 32 ubees
# 33 transparency-rights
# 34 soho-places
# 35 seaters
# 36 scanbuy
# 37 clem-0
# 38 willo
# 39 workwell
# 40 lombrosa-yacht
# 41 lystel-lighting-llc-led-nxt
# 42 hotels-day
# 43 alwayslab
# 44 my-cuistot-1
# 45 another-garde
# 46 barden-linguistics
# 47 pentalog
# 48 ulula
# 49 geomail
# 50 dynadmic
# 51 moneygoat
# 52 madyourself
# 53 infinite-flight
# 54 nocrmio
# 55 skylads
# 56 butterflyai
# 57 botify
# 58 adomik
# 59 waldo
# 60 extend
# 61 garou
# 62 pops
# 63 vyking
# 64 votebox
# 65 shade
# 66 hayo
# 67 glose
# 68 winddle
# 69 know-your-crew
# 70 under-mily-way
# 71 quasardb
# 72 iov
# 73 livelike
# 74 pathport
# 75 backmarket
# 76 digimind
# 77 winit
# 78 wheeli
# 79 variabl
# 80 vanguard-moto
# 81 upfluence
# 82 tinyclues
# 83 glass-file
# 84 gimli-project
# 85 talkus
# 86 tablet
# 87 switch-0
# 88 stryng
# 89 streamroot
# 90 speerit
# 91 socialix
# 92 smart-adserver
# 93 slimcut-media
# 94 s4m
# 95 rockaloo
# 96 rentalvestors
# 97 rebag
# 98 radseed
# 99 quantstack
# 100 pulpix
# 101 prose
# 102 press4kids
# 103 popsy
# 104 owkin
# 105 ollie
# 106 offtrack
# 107 mixer
# 108 keli-network
# 109 keenoby
# 110 joinery
# 111 idviu
# 112 hugging-face
# 113 freshplanet
# 114 flyinside
# 115 enyx
# 116 eachscape
# 117 deeploop
# 118 cramberry
# 119 cools
# 120 chili-piper
# 121 afineur
# 122 adsoutloud
# 123 adoreme
# 124 adikteev
# 125 ifeelsmart
# 126 blink-media-inc
# 127 squareplan
# 128 predictee
# 129 kitndo
# 130 replika-software-llc
# 131 my-tutor-speaks-french
# 132 equancy
# 133 wellbots
# 134 vuble
# 135 herow
# 136 55-data-company
# 137 fincons-group
# 138 babylon-farm
# 139 streamlinewatch
# 140 frogans-addresses-all
# 141 mazen
# 142 tcomposites-llc
# 143 very
# 144 mailjet
# 145 teach
# 146 invivox
# 147 1day-online
# 148 cybelangel
# 149 plume-labs
# 150 efficace-startups-platform
# 151 adyoulike
# 152 french-accelerator-0
# 153 tilkee
# 154 klaxoon
# 155 sparkup-0
# 156 magency-1
# 157 commanders-act
# 158 criteo-0
# 159 insuite
# 160 silver-credit
# 161 hi-commerce
# 162 algama
# 163 sinequa-corp
# 164 easymovie
# 165 sesamm
# 166 paws-en-vogue
# 167 outscale
# 168 planetassurcom
# 169 listenonrepeat
# 170 launchmetrics
# 171 adwantedcom
# 172 datawords
# 173 placemeter
# 174 kpler
# 175 cognik
# 176 tondo
# 177 theodo
# 178 sublime-skinz
# 179 startupbootcamp
# 180 feeligo
# 181 stilog-inc
# 182 easyship
# 183 invibes-advertising
# 184 bubble
# 185 spark-labs
# 186 hudson-mind
# 187 ryze-new-york
# 188 french-wink
# 189 storefront
# 190 stickyadstv
# 191 oliver
# 192 ily-pre-vente
# 193 news-o-matic
# 194 synthesio
# 195 voice-polls
# 196 sunrise
# 197 cord
# 198 clarityad
# 199 topi
# 200 vestiairecollective
# 201 tvty
# 202 criteo
# 203 teads
# 204 callr
# 205 yuzu
# 206 devialet
# 207 ezakus
# 208 shapr
# 209 vuble-0
# 210 secret-media
# 211 bandsintown
# 212 shopping-feed
# 213 nuxeo
# 214 tunsy-ios
# 215 curioos
# 216 keymetrics
# 217 dailymotion
# 218 aircall
# 219 dashlane
# 220 adways
# 221 sketchfab
# 222 dataiku
# 0 jobgo
# 1 fgubox
# 2 seat-compare
# 3 maillotio
# 4 safe
# 5 alltrippers
# 6 173tech
# 7 brandphic
# 8 mention-me
# 9 ontvlab
# 10 etzouelearningcom
# 11 bexpat
# 12 coorganiz
# 13 spartera
# 14 upslide
# 15 karma
# 16 coservit
# 17 mi-casa-es-tu-casa
# 18 jurisdocs
# 19 convelio
# 20 combiencoutemonsiteinternet
# 21 kylii-kids
# 22 agilismobilia
# 23 combiencoutemonapp
# 24 winnow-solutions
# 25 eazy-law
# 26 guestready-0
# 27 novamint
# 28 independent-calculation-agent-ica
# 29 elise-technologies
# 30 autocerfa
# 31 seaters
# 32 healsy
# 33 krispy-krush-limited
# 34 duffel
# 35 sequencework
# 36 mobip
# 37 slimpay
# 38 another-garde
# 39 mangopay
# 40 zotcar
# 41 skylads
# 42 turnstile
# 43 livelike
# 44 avalor
# 45 miuros
# 46 onestock
# 47 upclear
# 48 peex
# 49 cogiteo-0
# 50 1001audios
# 51 talkwalker
# 52 truerent
# 53 ip-trust
# 54 edoki-academy
# 55 helping-pong
# 56 taste-movies
# 57 teazit
# 58 facilit-immocom
# 59 trade-quorum
# 60 herow
# 61 sweet-inn
# 62 visyond
# 63 my-shopping-date
# 64 ez-workspace
# 65 paytoo
# 66 startup-maker
# 67 semantiweb
# 68 55-data-company
# 69 fincons-group
# 70 matchplace
# 71 zestmeup
# 72 appstud
# 73 verticalsoft
# 74 receipt-bank-france
# 75 realytics
# 76 talents4
# 77 connecttogether-inc
# 78 ispark-digital
# 79 mailjet
# 80 latelier-des-chefs
# 81 gradbase
# 82 efficace-startups-platform
# 83 green-park-content
# 84 synswap
# 85 adyoulike
# 86 yik-yak
# 87 olystix
# 88 luxuryboat
# 89 optimicdn
# 90 web-geo-services
# 91 leniomed-ltd
# 92 tradywine
# 93 telequid
# 94 globcoin
# 95 mobkoi
# 96 myddleware
# 97 schwartz-consulting
# 98 wing
# 99 sinequa-corp
# 100 agil-technologies
# 101 eudoweb
# 102 usmile
# 103 deezer
# 104 fanpass
# 105 yeeply-0
# 106 festicket
# 107 bestfootball
# 108 le-petit-ballon-uk
# 109 internshipmapper
# 110 business-o-feminin
# 111 running-heroes
# 112 cronycle
# 113 where-are-you-now-ltd
# 114 b-reputation
# 115 evasion-voyage-0
# 116 je-veux-1-truc
# 117 launchmetrics
# 118 lofty-city
# 119 voulez-vous-parler-ltd
# 120 appchocolate
# 121 seo-social-web
# 122 adwantedcom
# 123 artelys
# 124 re
# 125 mytutorabroad
# 126 uriji-jami
# 127 gocardless
# 128 idealwine
# 129 bsave
# 130 rentez-vous
# 131 dalou
# 132 alertfilm
# 133 vabbleco
# 134 kpler
# 135 fiftyfor
# 136 synoptica
# 137 lyribox
# 138 b9lab
# 139 goomeo
# 140 cedexis
# 141 lemon-way
# 142 vinoa
# 143 findoc
# 144 thank-you-ted
# 145 pusher
# 146 w3
# 147 sponsorize
# 148 frenchdigital
# 149 vivastreet
# 150 diune
# 151 xrapid
# 152 unisphere
# 153 book-everyone
# 154 techfugees
# 155 spacily
# 156 o-sable
# 157 neva-aerospace
# 158 moteefe
# 159 mokee
# 160 migreat
# 161 luckylink-staff-recruitment
# 162 le-salon
# 163 keepek
# 164 hiroes
# 165 gallinee
# 166 foodmood
# 167 emolument
# 168 actiom
# 169 kuarix
# 170 medicanimal
# 171 rougefrog
# 172 peak
# 173 hiveworks-ltd
# 174 yoyo-games
# 175 wisembly-0
# 176 voyageprivecom
# 177 vestiaire-collective
# 178 utelly
# 179 tramonex
# 180 tondo
# 181 tictrac
# 182 theodo
# 183 house-shop
# 184 mozoo
# 185 sublime-skinz
# 186 startupbootcamp
# 187 shopcade
# 188 path-motion
# 189 nexmo
# 190 mirakl-0
# 191 merci-maman
# 192 madecom
# 193 luckycycle
# 194 linkfluence
# 195 kantox
# 196 iwoca
# 197 iron-group
# 198 feelunique
# 199 evaneos
# 200 edit-placecom
# 201 ogury
# 202 ovh
# 203 numberly
# 204 frenchconnect-london
# 205 french-pass
# 206 easyroommatecom
# 207 pradeo
# 208 edgar-people
# 209 finalcad
# 210 storefront
# 211 devialet
# 212 neteven
# 213 fifty-five
# 214 seeveeze
# 215 mazeberry
# 0 benu-blanc
# 1 ficha
# 2 nolio
# 3 champiloop
# 4 beelse
# 5 shared
# 6 maxicours
# 7 toaztr
# 8 wookal-0
# 9 marvelock
# 10 teams-connect
# 11 activhandi
# 12 allorank
# 13 runmotion-coach
# 14 rodacom
# 15 trive-1
# 16 transfertpro
# 17 activedomicile
# 18 mmh
# 19 comongo-0
# 20 talent-program
# 21 snowleader
# 22 pdc-line-pharma
# 23 helplicit
# 24 wattapro
# 25 diabeloop
# 26 waga-energy
# 27 remedee-labs
# 28 ski-family
# 29 legalissimo
# 30 solean
# 31 vesta-system
# 32 scintil-photonics
# 33 nextperience-sas
# 34 veertus
# 35 graaly
# 36 wizbii
# 37 kelobeez
# 38 dcbrain
# 39 vert-cameleon
# 40 argent360
# 41 leviatan
# 42 coservit
# 43 myocadeau
# 44 succession-service
# 45 klevr
# 46 primo1d
# 47 seoquantum
# 48 elearnis
# 49 qweekle
# 50 combiencoutemonsiteinternet
# 51 cideo
# 52 colisbree
# 53 red-motion
# 54 hunimalis
# 55 combiencoutemonapp
# 56 international-plant-selection
# 57 vates
# 58 new-body-technology
# 59 hexade
# 60 toclic
# 61 orok
# 62 domnexx
# 63 isorg
# 64 hydrao
# 65 bluepixelcie
# 66 mobile-practice
# 67 pixyl
# 68 wattamate
# 69 la-charrette
# 70 profonia
# 71 axway
# 72 skewerlab
# 73 reactivip
# 74 kizbat
# 75 e-glue
# 76 kpitaine
# 77 cryptomofo
# 78 helloways
# 79 eken
# 80 gtx-gamer
# 81 digital-skills-foundation
# 82 inceptive
# 83 payxpert
# 84 aledia
# 85 mon-commercant
# 86 cawice-camera-de-surveillance-gratuite-application-android
# 87 odit-e
# 88 stimergy
# 89 factoryz
# 90 enhancia
# 91 airnodes
# 92 hap2u
# 93 myexpatus
# 94 funky-sound-studio
# 95 innoradiant
# 96 garantie-decennalemaison
# 97 groupe-axone-franchise-cloud
# 98 isoft
# 99 drone-interactive
# 100 my-digital-buildings
# 101 sinao
# 102 eatsmart
# 103 spygen
# 104 zcost-management
# 105 prismo
# 106 fastpoint
# 107 solinki
# 108 solutions
# 109 modern-blocks
# 110 coopt-actionfr
# 111 kaperli
# 112 parking-telecom
# 113 kazidomi
# 114 koelis
# 115 reverso
# 116 skincar
# 117 ebds
# 118 myoeno
# 119 activity-lab
# 120 bookmoove
# 121 phonefix
# 122 certifian
# 123 reputaction
# 124 sylfen
# 125 chesk
# 126 hidnseek
# 127 isymarket
# 128 euveka
# 129 menuonline
# 130 innovisite
# 131 lrdhco
# 132 alpwise
# 133 aryballe-technologies
# 134 lancey-energy-storage
# 135 bixi-bluemint-labs
# 136 spoc-projet
# 137 seecar
# 138 loveboxlove
# 139 symbio
# 140 moovlab
# 141 caplogiciel
# 142 steadxp-sas
# 143 enlaps
# 144 skaping
# 145 octopus-joy
# 146 enerbee
# 147 inmotion-1
# 148 my-dso-manager
# 149 leti
# 150 punkers
# 151 webiaprod
# 152 referencement-du-pro
# 153 sublimed
# 154 elichens
# 155 xils-audio
# 156 minutedrone
# 157 talentsimmo
# 158 gaming-co
# 159 hd-media
# 160 wegoto
# 161 pharmanity
# 162 fidelisa
# 163 sas-sportscleek-rugbycleek
# 164 storhy
# 165 ticaticom
# 166 o-technology
# 167 webmarketing-booster
# 168 citizenapps
# 169 aux-petits-oignons
# 170 idosens
# 171 yeeply
# 172 fingerview
# 173 tenevia
# 174 technosens
# 175 second-guide
# 176 short-edition
# 177 codeffekt
# 178 biboard
# 179 hercule
# 180 commod
# 181 inmotion-0
# 182 joggin
# 183 zeemono
# 184 javise
# 185 digital-test-center
# 186 respawnsive
# 187 syndicio
# 188 bookingsync
# 189 drop-my-kids
# 190 cigale-wifi-yziact
# 191 apitrak
# 192 kookooning-kapt
# 193 anatoscope
# 194 verseo-cs
# 195 noviscore
# 196 sas-sport-tone
# 197 sheeps
# 198 tooeasy
# 199 non-universal-nuts
# 200 echy
# 201 menu-hebdo
# 202 pepper-site
# 203 mhikes
# 204 mots-damour
# 205 nivolog-peufdaddy
# 206 collibris
# 207 temponeo
# 208 hexo-pre-commande
# 209 closetoshop
# 210 artips
# 211 ocibokelles
# 0 nextflow-software
# 1 fonto-de-vivo
# 2 visio-pere-noel
# 3 nicolas-bremand-affaire
# 4 ereferer
# 5 close-env
# 6 tjikko
# 7 vos-id-en-3d
# 8 shade-technologies
# 9 petites-caves
# 10 spideer-agence
# 11 daqsan
# 12 spendways
# 13 gimfix
# 14 irys-photographie
# 15 ives
# 16 kelcab
# 17 peekin
# 18 beauteadom
# 19 maternice
# 20 ma-petite-popote
# 21 handiplanet-0
# 22 atom-computer
# 23 josepho
# 24 dashdoc
# 25 cedreo
# 26 lhyfe
# 27 impact-track
# 28 beesbusy
# 29 polytrans
# 30 helloresa
# 31 microej-0
# 32 agence-bee-yoo
# 33 mixity
# 34 origame
# 35 partners-finances
# 36 prestapp
# 37 imagination-machine
# 38 i-sep
# 39 largo
# 40 transway
# 41 akeneo
# 42 station-spatiale
# 43 itcam
# 44 ez-cloud
# 45 guest-suiteNJDQHFZ
# 46 crisp
# 47 stamps-internships
# 48 sterblue
# 49 arco
# 50 inlead
# 51 mr-suricate
# 52 graphilab
# 53 bunnymoney
# 54 forex-hero-trading-game
# 55 foxeet
# 56 collectif-energie
# 57 stimio
# 58 munut-edition
# 59 latelier-du-poupoupidou
# 60 naolink
# 61 unik-name
# 62 fiitli
# 63 car-expresso
# 64 e-cobot
# 65 iraiser
# 66 tranquil-it
# 67 mobidys
# 68 id-city
# 69 international-horizons
# 70 intuitive-robots
# 71 betterfly-tourism
# 72 teester
# 73 ensemble1job
# 74 zenika
# 75 guest-suit
# 76 smart-my-data
# 77 skippair
# 78 case-law-analytics
# 79 easilys
# 80 vite-mon-marche
# 81 jho
# 82 livli
# 83 diginamic
# 84 newdeal
# 85 doitabroad
# 86 audreytips
# 87 jloo
# 88 frequence-turf
# 89 realitim
# 90 invest-city
# 91 fifty-truck
# 92 kosmos
# 93 novyspec
# 94 velco
# 95 kiplin
# 96 pueribourse
# 97 listo-paye
# 98 trybu-nutrition
# 99 mon-beau-terroir
# 100 akken
# 101 sweet-show
# 102 playak
# 103 armor-3d
# 104 switch
# 105 authot
# 106 toot-sweet
# 107 garden-party
# 108 entrainement-handball
# 109 take-desk
# 110 helloextra
# 111 brain-start
# 112 huntool
# 113 de-rigueur-0
# 114 witivio
# 115 era-comm
# 116 strapp
# 117 shopopop
# 118 on
# 119 konnecticut
# 120 erdre-audio
# 121 french-view
# 122 com4events
# 123 hellocasa
# 124 my-expat
# 125 kindo
# 126 pairform
# 127 matlo
# 128 sowesign
# 129 kadri-signal
# 130 gensdeconfiancefr-trustedpeoplecom
# 131 meteojob
# 132 speachme
# 133 greesme
# 134 sowesign-0
# 135 kadran
# 136 boxn-services
# 137 linkbynet
# 138 10-vins
# 139 lunettes-au-logis
# 140 bescent
# 141 atmotrack
# 142 talend-1
# 143 meyko
# 144 gaspard-1
# 145 artefacts
# 146 myscript
# 147 jaitoo-events
# 148 family-facility
# 149 dropbird
# 150 govvva
# 151 vitavinum
# 152 my-pacs
# 153 mydesirchic
# 154 afrostream
# 155 quai-des-apps-0
# 156 listedenaissanceme
# 157 space-designer-3d
# 158 diyloc
# 159 sea-tags
# 160 leffete-papillonne
# 161 eqwall
# 162 uprigs
# 163 place-des-projets
# 164 eudoweb
# 165 kolime
# 166 made-france
# 167 bookgolf
# 168 guest-app
# 169 loomup
# 170 withapps
# 171 sharemysea
# 172 parkly
# 173 trainingloadpro
# 174 sportweez
# 175 wizeloop
# 176 score-nco
# 177 goalforever
# 178 qivivo
# 179 prismicio
# 180 queeny
# 181 objeko
# 182 oyatis
# 183 obeo
# 184 tousproducteurs
# 185 jobprod
# 186 we-craft-apps
# 187 gladys
# 188 atmoterra
# 189 cenareo
# 190 talentroc-solutions
# 191 lucca
# 192 keople
# 193 weenat
# 194 clever-cloud
# 195 trad-online
# 196 tentation-fromage
# 197 gif-hit
# 198 mynewstartup
# 199 immodvisor
# 200 kiwatch
# 201 organilog
# 202 cashway
# 203 kinow
# 204 cavavincado
# 205 lengow
# 206 startupers
# 207 iadvize
# 208 check-my-website
# 209 mycookr
# 0 capbloc
# 1 vaonis
# 2 boc-doc
# 3 oppi
# 4 foodr
# 5 locango
# 6 local
# 7 apero-gourmet
# 8 lesmarketing
# 9 agence-geasy
# 10 uvoji-tzic
# 11 originailes
# 12 nature-az
# 13 tipsi
# 14 hifivework
# 15 quicktext
# 16 montpellierrent
# 17 smart-services
# 18 dgtalstory
# 19 imperiumtm
# 20 mamie-note
# 21 osmozis
# 22 homki
# 23 la-vie-naturelle
# 24 market-solutions
# 25 wisud
# 26 dealburnfr
# 27 il-etait-un-fruit
# 28 talkspirit-0
# 29 kinvent
# 30 winnr
# 31 laboxy
# 32 wifitmedia
# 33 thestylerushcom-maison-koly-bottier-intemporel
# 34 studio-gazoline-0
# 35 trakmy
# 36 peoplespheres
# 37 cayceo
# 38 bazimo
# 39 le-guide-de-la-vue
# 40 panoraven
# 41 dvb-international
# 42 inadvance-box
# 43 les-petits-mandarins
# 44 la-valeriane
# 45 proabono
# 46 keetiz
# 47 lundi-matin
# 48 swile
# 49 sereema
# 50 panjee
# 51 daneel
# 52 e-tumba
# 53 smart-corner
# 54 usetool
# 55 magicpallet
# 56 atlantide
# 57 sportihome
# 58 ma-petite-assiette
# 59 vogo
# 60 mon-chasseur-immo
# 61 elements
# 62 ergo-concepts
# 63 wepub
# 64 kikanou
# 65 skeyetech
# 66 simcure
# 67 biodol-therapeutics
# 68 oworkers
# 69 mon-entretien-de-chaudiere
# 70 surgimab
# 71 mint-energie
# 72 specialist-wanted
# 73 lerezopro
# 74 diginamic
# 75 bci-pharma
# 76 pronocontest
# 77 exatech
# 78 tell-elevage
# 79 netheos
# 80 vesta
# 81 le-petit-beret
# 82 masmarthome
# 83 burostation
# 84 bonetag
# 85 iminnov-sas
# 86 ezspace-corp
# 87 solunea
# 88 wilynet
# 89 spi-software
# 90 origine-locale-certifiee
# 91 voyagir
# 92 groomi
# 93 insitio
# 94 classequine
# 95 safelight
# 96 doyoogo
# 97 sofacto
# 98 sublivin
# 99 beyond
# 100 athlete-avenuecom
# 101 upper-play
# 102 french-view
# 103 r3cit
# 104 winepass
# 105 stayhome
# 106 pricecomparatorpro
# 107 realie
# 108 revinax
# 109 crossshopper
# 110 bimpair-pff
# 111 eden
# 112 scanmyplace
# 113 my-wonderful-kids
# 114 realistis
# 115 kyomed-innov
# 116 rovercash
# 117 bear-sas
# 118 artmajeur
# 119 codingame
# 120 synapse
# 121 web-geo-services
# 122 matchupbox
# 123 vitavinum
# 124 mbs-group
# 125 le-local-me-regale
# 126 oandb
# 127 crossshopper-mercimerci
# 128 inside-montpellier
# 129 westi
# 130 monportailrh
# 131 ambassade-de-lalimentation-association-asard
# 132 mobiler2d2
# 133 servicesyou
# 134 locavorium
# 135 juriscloud
# 136 aquafadas
# 137 urban-bike-city-tour
# 138 fitnet-manager
# 139 courts-circuits
# 140 1001experts
# 141 ekyno-company
# 142 zerosix
# 143 twlivenet
# 144 ela-innovation
# 145 comiti
# 146 gyms-square
# 147 convicrea
# 148 bienmangercom
# 149 bricks-0
# 150 virdys
# 151 cheque-sante
# 152 comwatt-sas
# 153 anatoscope
# 154 appvizer
# 155 esii
# 156 appi-technology
# 157 innership
# 158 talkspirit
# 159 fruition-sciences
# 160 1001tweets
# 161 seclab
# 162 dropy
# 163 ski-discount-france
# 164 kuzzle
# 165 le-vrai-service-client
# 166 pradeo
# 167 wemap
# 168 enerfip
# 169 matooma
# 170 ebook-lr
# 171 smoove
# 172 stratoz
# 173 soonmap
# 174 la-press-tech
# 175 wearelearning
# 176 wasr
# 177 saas-invaders
# 178 izika
# 179 swopr
# 180 memorink-beta
# 181 pragmatic-entrepreneurs-news
# 182 enov-formation
# 183 wesavoirfaire
# 184 bime-analytics
# 185 wezr
# 186 pragmatic-entrepreneurs
# 187 snapkin
# 188 tellmeplus
# 189 nelis
# 190 wibuzzit
# 191 kwizzeo
# 192 noospher
# 193 eneo
# 0 kirae
# 1 kalisport
# 2 frigo-magic
# 3 medinthepocket
# 4 odopass
# 5 ipaidthat
# 6 chaine-de-masque-le-petit-cordon
# 7 locntour
# 8 marche-delice
# 9 spycin
# 10 leeve
# 11 buildway
# 12 petit-brunch
# 13 simango
# 14 moovency
# 15 onewave
# 16 novolinko
# 17 culturepay
# 18 procsea
# 19 nextoyou
# 20 tibot-technologies
# 21 waryme-0
# 22 cimtech
# 23 cailabs
# 24 logpickr-0
# 25 nanocode
# 26 breidal
# 27 ae2-agence-web
# 28 foodologic
# 29 1kubator-rennes
# 30 get-it
# 31 maison-de-leventail
# 32 cloudeezy
# 33 advalo
# 34 leocare
# 35 cabinet-morin-conseil
# 36 agriloops
# 37 da-business-development-cote-ouest
# 38 ariadnext
# 39 famileo
# 40 lexilight
# 41 fiitli
# 42 zero-phyto-pro
# 43 certytech
# 44 unseenlabs
# 45 guide-chargeurfr
# 46 open-agora
# 47 e-mage-3d
# 48 askbluai-happy-blue-fish
# 49 ekolis
# 50 zenika
# 51 kemwatt
# 52 happywait
# 53 keepeek
# 54 le-petit-cordon
# 55 amazjob
# 56 msp-smartmoov
# 57 check-visit
# 58 wi6labs
# 59 haapie
# 60 adalong
# 61 zerudi
# 62 travelbudds
# 63 selldorado
# 64 hodnos
# 65 whoomies
# 66 docndoc
# 67 ip-trust
# 68 blockchainyourip
# 69 immersive-therapy
# 70 heyliot
# 71 orfeo
# 72 tech4race
# 73 qare
# 74 1026
# 75 labigaddress
# 76 dooloo
# 77 my-cuistot-0
# 78 dometech
# 79 neature
# 80 drivequant
# 81 wedev-group
# 82 akken
# 83 bed-wet
# 84 radiosparx-france
# 85 africa-overseas
# 86 clay-inc
# 87 kelbillet
# 88 sinademploi
# 89 book-meonline
# 90 coachenko
# 91 newcy
# 92 cookorico
# 93 isol-pro-protection-incendie-passive
# 94 cma-connect
# 95 imatag
# 96 buildiz
# 97 conjecto
# 98 dolmen
# 99 sizar
# 100 hellocasa
# 101 bookbeo
# 102 ama
# 103 weenjoy
# 104 forcity
# 105 klaxoon
# 106 dropbird
# 107 bdegker
# 108 agence-ldp-acronyme-de-lunettes-de-pub
# 109 3d-sound-labs
# 110 lapagelocalecom
# 111 arvey
# 112 ouest-emploi-chr
# 113 we-recruit
# 114 eqwall
# 115 ubiflow
# 116 area-i3-0
# 117 we-love-customers
# 118 claim-ship
# 119 keosu
# 120 tactilia
# 121 syneika
# 122 mapui-labs
# 123 une-jolie-idee
# 124 apizee
# 125 carbip
# 126 getclother-smart-fashion-together
# 127 goyavi
# 128 alentoorfr
# 129 get-yogi
# 130 la-boutonniere
# 131 aladom
# 132 data2b
# 133 smartviser
# 134 pro-spare
# 135 move4ideas
# 136 zetapush
# 137 le-maitre-cube
# 138 ariase-group
# 139 energiency
# 140 enensys-technologies
# 141 eliga
# 142 edcom
# 143 yadlo
# 144 pinthemall
# 145 rewind
# 146 shopus
# 147 mylodgeventcom
# 148 willid
# 149 seo4ajax
# 150 dareboost
# 151 suivico
# 152 urway
# 0 green-lotus-asia
# 1 statrys
# 2 meri-digital
# 3 guide-me-hong-kong
# 4 symphony
# 5 sediug
# 6 ontvlab
# 7 ohmybundle
# 8 sleek
# 9 okibook-ltd
# 10 binoclespaschers
# 11 merci-dandy
# 12 talvala
# 13 weprod
# 14 weprod-0
# 15 luxe-observer
# 16 guestready-0
# 17 unikeys
# 18 wynd
# 19 sagit-solutions
# 20 cpecf
# 21 lombrosa-yacht
# 22 syncontrol-technology-ltd
# 23 osol
# 24 get-clicks
# 25 drive-digital-analytics-specialists
# 26 helperchoice
# 27 wiredcraft
# 28 55-data-company
# 29 jeanuine
# 30 xxii-group
# 31 aoc-insurance-broker
# 32 fizen
# 33 un-role-jouer
# 34 centralapp
# 35 beeboss
# 36 tricycle-office
# 37 helperplace
# 38 linkee
# 39 frenchpulse
# 40 hubble
# 41 madeinvote
# 42 homagencycom
# 43 audit-artisan
# 44 fudo
# 45 cypheme
# 46 clickndress
# 47 curiosity-china
# 48 lincko
# 49 2hands-sas
# 50 balkash-capital
# 51 hellocasa
# 52 noa-labs
# 53 zhi-you-ami-premium
# 54 vr-here
# 55 daxue-conseil
# 56 linkbynet
# 57 resolving
# 58 openairlines
# 59 forcity
# 60 clim8
# 61 moona
# 62 b2lunch-ltd
# 63 japet-medical-devices
# 64 e-learn2grow
# 65 my-webspot-0
# 66 key2cell
# 67 lookdiary
# 68 my-webspot
# 69 mbs-group
# 70 easy-bacchus
# 71 hotelquickly
# 72 nconcepts
# 73 workshop
# 74 juke
# 75 coolhobo
# 76 outscale
# 77 influence-360
# 78 invivogen-limited
# 79 oodrive
# 80 aprivacy
# 81 uint-asia-pacific-limited
# 82 talkpush
# 83 idealwine
# 84 cg-mobile
# 85 onthelist
# 86 masutado
# 87 myfairtool
# 88 datawords
# 89 hirely
# 90 texturessaveurs
# 91 lepetitjournalcom-hong-kong
# 92 y-less
# 93 supernova
# 94 carlipa
# 95 ubudu-asia
# 96 anekdote
# 97 ladyplans
# 98 topdoc
# 99 digitalin-consulting
# 100 teleonomy
# 101 niche-networks-ltd
# 102 mercurr
# 103 ls-ware
# 104 digital-business-lab
# 105 lccs
# 106 ad-studio
# 107 w-hub
# 108 wassa
# 109 visionaries-777-limited
# 110 wild-heart
# 111 emie-lab
# 112 omate
# 113 gatecoin
# 114 buymedesign-bed-designers
# 115 easyship
# 116 captain-verify
# 117 popmap
# 118 tofupay
# 119 storefront
# 120 remailder
# 121 fifty-five
# 0 drone-supervision
# 1 fidzee-0
# 2 fair-and-smart
# 3 myfitfiles
# 4 aston-itrade-finance
# 5 partners-finances
# 6 vivoka-0
# 7 tresorio
# 8 uppler
# 9 just-mining
# 10 hoomusic
# 11 owlie
# 12 yeeld
# 13 clevoff
# 14 zest
# 15 goworkco
# 16 defi-informatique
# 17 fairsmart
# 18 linote
# 19 festihome
# 20 mydemenageur
# 21 emit-conception-electronique
# 22 pushoose
# 23 atelier-tb
# 24 oworkers
# 25 teogest
# 26 ezbeez
# 27 c3n-studio
# 28 braceletchic
# 29 kiwi-backup
# 30 easyteo
# 31 groww
# 32 gossy
# 33 alacrite-france
# 34 beampulse
# 35 kidocine
# 36 modelefiscal
# 37 vr-time
# 38 leonart-artpadart
# 39 fiestaclean
# 40 wiw
# 41 tallyos-france
# 42 factoryz
# 43 berman-sarrazin
# 44 eldorado-immobilier
# 45 orisecure
# 46 villa-balicom
# 47 lhuile-barbe
# 48 devisman
# 49 pluus-your-online-world-one-word
# 50 glamuse
# 51 premedit-running-care
# 52 oko
# 53 zabilo
# 54 travelys
# 55 legipermis
# 56 tree-science
# 57 we-visite
# 58 pur-conseil
# 59 xp-digit
# 60 chez-vianneyfr
# 61 monabee
# 62 europe-tp
# 63 novall
# 64 teepy-entrepreneur
# 65 fulldeal
# 66 mybrocante
# 67 linkio
# 68 1001-atelierscom
# 69 antsroute
# 70 potloc-0
# 71 sencrop
# 72 nurgo-software
# 73 hellocasa
# 74 acreos
# 75 1day-online
# 76 spinali-design
# 77 digitsole
# 78 le-coq-style
# 79 citizencam
# 80 gemmetiz
# 81 greenberry
# 82 dyrun
# 83 scalable-graphics
# 84 brewnation
# 85 hubin-0
# 86 flaternity
# 87 piggou
# 88 sesamm
# 89 digital-instore
# 90 evi
# 91 90tech
# 92 vtc-booking
# 93 click2map
# 94 bluepad
# 95 upgrade-codeorg
# 96 woozjob
# 97 sidonie
# 98 sutter-event
# 99 quickcontest-sas
# 100 festmapper
# 101 divacore
# 102 roomokay
# 103 mymusic-teacher
# 104 lp-studio
# 105 compta-clementine-la-comptabilite-sans-les-pepins
# 106 concept-store-3d
# 107 mymusicteacher
# 0 les-cles-de-ma-cave
# 1 toolpad
# 2 edmill
# 3 colibree-intergeneration
# 4 thelma-rose
# 5 eloa-0
# 6 home-fit-training
# 7 passingshot
# 8 loop-me
# 9 digitaliaa
# 10 rapidle-0
# 11 seekyo
# 12 cryptelite
# 13 french-coco-box
# 14 euvitis-formations
# 15 metrocoli
# 16 civitime
# 17 partners-finances
# 18 ayoub-seo
# 19 monkey-tie
# 20 greenponik
# 21 fedmind
# 22 geovelo
# 23 agrikaido
# 24 scanopy
# 25 x
# 26 nexterite
# 27 cocote
# 28 lougage
# 29 edubravo
# 30 purecontrol
# 31 rapidle
# 32 mascara-renewable-water
# 33 devenez-proprio
# 34 skwirrel
# 35 olive-thome-degustent
# 36 h2i
# 37 mysetupco
# 38 welcomr
# 39 pentalog
# 40 discovery-partner
# 41 evidences-3d
# 42 eliraweb
# 43 le-smartsitting
# 44 book-and-plug
# 45 dom-one
# 46 agrifind
# 47 i-connect
# 48 tesla-4u-0
# 49 janasense
# 50 eveia
# 51 enjoyup
# 52 caressea
# 53 exportmates
# 54 villa-balicom
# 55 groupe-axone-franchise-cloud
# 56 hopoli
# 57 foxie
# 58 styx-students
# 59 ip-trust
# 60 comeon-sport
# 61 mets-vins
# 62 gosense
# 63 la-box-quejadore
# 64 maxicoffeecom
# 65 my-serious-game
# 66 findynamics
# 67 learny-box
# 68 barnaby
# 69 lekooa
# 70 on
# 71 saos
# 72 kindo
# 73 acep
# 74 abcommerces
# 75 design-screen-hd
# 76 make-manufacture
# 77 opitrip
# 78 lecoinsolidairecom
# 79 tripilli
# 80 artefacts
# 81 h2h
# 82 dooliz
# 83 you-trust-0
# 84 le-coin-solidaire
# 85 bubbles-company
# 86 my-univers-domotique
# 87 you-trust-1
# 88 comptacom
# 89 trouvetoncommercialcom
# 90 positivr
# 91 joggin
# 92 hypemyplace
# 93 gaspard-0
# 94 nodon
# 95 hl2-group
# 96 stile
# 97 savane-vision
# 98 publicite-moi
# 99 les-georges
# 100 wazashirt
# 101 aperocelib
# 102 statuzer
# 103 interviewapp
# 104 nowly
# 0 troispetitspoints
# 1 webmecanik
# 2 smiirl
# 3 a2ia
# 4 ab-tasty
# 5 sponsokit
# 6 contentsquare
# 7 regiondo-0
# 8 concerty
# 9 tellows
# 10 upslide
# 11 gearscoretm-akena-technologies
# 12 gingalab
# 13 combiencoutemonsiteinternet
# 14 combiencoutemonapp
# 15 forexfix
# 16 filestage
# 17 capsix-robotics
# 18 sentryo
# 19 bimdataio
# 20 digit-me
# 21 steerio
# 22 cloub
# 23 ellistra
# 24 wingly
# 25 free2move
# 26 luko
# 27 menutech
# 28 mangopay
# 29 panthea
# 30 ykone
# 31 worldia
# 32 webedia-group
# 33 vaniday
# 34 unu
# 35 ubisoft
# 36 traffic-hunter
# 37 tabmo
# 38 singa
# 39 rousseau-park
# 40 request-network
# 41 recare-solutions
# 42 poissonneriecom
# 43 parrot
# 44 livebird
# 45 la-ruche-qui-dit-oui
# 46 hotel-hero
# 47 histalim
# 48 heypet
# 49 flowigo
# 50 affluences
# 51 altagram-gmbh
# 52 nocrmio
# 53 airteam
# 54 access-watch
# 55 1aim
# 56 virail
# 57 payxpert
# 58 adikteev
# 59 miuros
# 60 teamleader
# 61 whoomies
# 62 qare
# 63 global-seafood-sas
# 64 pomp
# 65 coworkies
# 66 vescape-fitness-shop
# 67 realytics
# 68 capital-implant
# 69 creative-geeks
# 70 mailjet
# 71 soundsuit
# 72 gocater
# 73 urbam-bamboo-bikes
# 74 itinsell
# 75 forcity
# 76 jobinberlin
# 77 hupp
# 78 criteo-0
# 79 white-kitchen
# 80 vescape
# 81 productive-mobile
# 82 holidu
# 83 deezer
# 84 civocracy
# 85 oodrive
# 86 doctolib
# 87 itec-pro
# 88 cenareo
# 89 startupbootcamp
# 90 evaneos
# 91 ovh
# 92 blablacar
# 93 sigfox-0
# 94 edgar-people
# 95 synthesio
# 96 criteo
# 97 le-wagon-ondemand
# 98 aircall
# 99 qwant
# 100 drivy
# 101 iadvize
# 0 shareconfrere
# 1 panodyssey
# 2 solar-tree-europ-0
# 3 tryon
# 4 mycater
# 5 meet-business-students
# 6 gradeup
# 7 cocoplant
# 8 amabilis
# 9 pomelo-factory
# 10 balzeo
# 11 oscar-referencement
# 12 alfred-meeting-0
# 13 webmaniac
# 14 oscar-black
# 15 happypal
# 16 datacook
# 17 be-sport
# 18 uncle-j
# 19 onlyone
# 20 gilbert-alias-la-pepite-du-stockage
# 21 newbrands
# 22 rocket-school
# 23 artpoint
# 24 super-webmaster
# 25 troov
# 26 pharow
# 27 busterai
# 28 pandobac
# 29 televets
# 30 paykrom
# 31 olvid
# 32 mon-expert-du-droit
# 33 qovery
# 34 fecamp-services-0
# 35 noly-compta
# 36 sofa-club
# 37 cotizupcom
# 38 charge
# 39 sxo-digital
# 40 myrmoo
# 41 we-are-rewind
# 42 printadom
# 43 teqoya-0
# 44 rotam-mobility
# 45 meri-digital
# 46 idopia
# 47 rue-rangoli
# 48 meerodrop
# 49 charging-place
# 50 each-one-ex-wintegreat
# 51 vianova
# 52 comeeti
# 53 berty-technologies
# 54 decollab
# 55 youfood
# 56 daniwoo
# 57 aptero
# 58 bluedigo
# 59 b-cubeai
# 60 winwez
# 61 mayday
# 62 le-coq-gourmet
# 63 lumapps-0
# 64 circular
# 65 yoonix
# 66 influentia
# 67 agence-ralph
# 68 startup-cemetery
# 69 vivadata
# 70 accenta
# 71 primaa
# 72 renforr
# 73 moka
# 74 sancare
# 75 mediatech
# 76 merci-facteur
# 77 kidiwe
# 78 cevidentia
# 79 french-connected-device-regulatory-advisors-fcdra
# 80 digdeo
# 81 monpuis
# 82 ween
# 83 seaclick
# 84 yogoko
# 85 e-takescare
# 86 hostabee
# 87 optibudget
# 88 les-plaisirs-fruites
# 89 splendy
# 90 footinho
# 91 scale-1-portal
# 92 acheter-francais
# 93 funemarket
# 94 oktopusprime
# 95 actimeety
# 0 doqboard
# 1 datexim
# 2 mon-assistant-numerique
# 3 paille-en-paille
# 4 docndoc-0
# 5 cherche-mon-nid-0
# 6 sasp-services
# 7 topovideo
# 8 sellingathome
# 9 roav7
# 10 mariage-en-normandie
# 11 sinay-maritime-data-solution
# 12 reseaupro
# 13 larinella
# 14 da-business-development-cote-ouest
# 15 map-patho
# 16 novelstra
# 17 maison-sassy
# 18 fase-industries
# 19 protecsom-laboratoire
# 20 s2f-network
# 21 robocath
# 22 keyveo
# 23 green-research
# 24 haincourt-sas-dealer-de-coque
# 25 koalame
# 26 eyye
# 27 monhoteliercom
# 28 evup-solutions
# 29 open-mind-innovation
# 30 stars-wombee
# 31 kudify
# 32 itekube
# 33 heptaward
# 34 green-systemes
# 35 dejamobile
# 36 coding-school
# 37 bearstudio
# 38 bimco
# 39 atexio
# 40 ripayon
# 41 message-business
# 42 flamefy
# 43 okast
# 44 b-moville
# 45 bestyphone
# 46 juripay
# 47 paytweak
# 48 mychauffagecom
# 49 familink
# 50 piecesafournir
# 51 camping-car-assure
# 52 toutpaie
# 53 omicx
# 54 zcost-management
# 55 holibag
# 56 godblessyoo-golnpeace
# 57 cookrs
# 58 event-bots
# 59 wisper
# 60 aptiko
# 61 bubble-bd-comics-mangas
# 62 red-alert-labs-0
# 63 1to1progress
# 64 bottle-cream
# 65 wepetsitty
# 66 studiosport
# 67 spread
# 68 familibox
# 69 driveyourtools
# 70 saagie
# 71 foreachcode
# 72 godblessyoo
# 73 margotte-tournicote
# 74 vrv-prod
# 75 marche-privecom
# 76 wibees
# 77 wetruck
# 78 vivent
# 79 paygreen
# 80 prs-plastrepairshop
# 81 wombee
# 82 kayo
# 83 ctexdev
# 0 spreadpress
# 1 photographe-evjf
# 2 signaturit-solutions-sl
# 3 gift-campaign

# %%
dataframe = pd.DataFrame(columns=['Name','urlwebsite']) 
dataframe["Name"]=startups[:len(startups_urls)]
dataframe["urlwebsite"]=startups_urls
dataframe.to_csv("data.csv")
dataframe.head(10)
# Out:
#            Name                    urlwebsite
# 0     pandaloc       https://www.pandaloc.com
# 1     1food1me           https://1food1me.com
# 2      appines        https://www.appines.fr/
# 3    interstis          https://interstis.fr/
# 4     kshuttle    https://www.kshuttle.io/fr/
# 5     ticketin         http://www.ticketin.fr
# 6  citizenwave   https://www.citizenwave.com/
# 7       darlow        https://darlowparis.com
# 8    deepsight      https://www.deepsight.io/
# 9    teambrain          https://teambrain.fr/

# %%
import pandas as pd
dataframe=pd.read_csv("data_version_1.csv")
dataframe["Description"]=dataframe.apply(lambda row: get_Description(row["urlwebsite"],False),axis=1)
dataframe.to_csv("data.csv")
dataframe.head(10)
# Out:
# https://1food1me.com
# https://www.appines.fr/
# https://interstis.fr/
# https://www.kshuttle.io/fr/
# http://www.ticketin.fr
# https://www.citizenwave.com/
# https://darlowparis.com
# https://www.deepsight.io/
# https://teambrain.fr/
# https://www.luxurynsight.com/
# https://www.captainachat.com
# https://trapeze-des-mascareignes.site/
# http://www.meet-bs.com
# https://www.serialtesteur.fr/
# https://www.feelgoodvinyl.com
# https://melotick.com
# http://examin.eu
# https://www.amabilis.fr/
# https://crowdsec.net/
# https://lici.fr/
# http://datasoluce.com/
# https://tomojo.co/
# https://keeze.co/
# https://www.koyeb.com/
# https://spectraltms.com/
# https://www.auto-ecole.net/
# https://www.campings.com/fr/
# http://www.avekapeti.com
# http://www.skiptax.com
# https://xval.fr/
# https://digitalessence.fr/
# https://deftsoftware.com/
# https://spacesense.ai/
# http://merca.team/
# https://www.kurmi-software.com/fr/
# https://www.sekoia.fr/
# https://join-implement.com/
# https://www.ekestrian.com/
# Unexpected error: HTTPSConnectionPool(host='www.ekestrian.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.hellojoko.com/
# http://www.ethikdo.co
# https://okube-attribution.com/
# https://sightness.com/
# https://yvy-mate.fr
# https://www.pandor-culture.com/
# https://multis.co/
# https://choosemycompany.com/fr/
# https://pandascore.co/
# https://mecagoo.com/
# https://hedee.co
# https://klaxo.fr/
# https://pronoo.ai
# http://easyblue.io
# http://www.popee.co
# https://www.yelda.ai/
# https://voulez-vous.club
# https://www.mariaschools.com/
# https://paraswap.io/
# https://welcomeatwork.com/
# https://www.qobuz.com/fr-fr/discover
# https://www.ubble.ai/fr
# https://testingstudio.io/
# https://www.teamii.co
# https://patrivia.net/home
# https://www.laboucherougeparis.fr/
# https://www.wechooz.fr
# https://www.dae-pro.fr/
# http://www.goodvest.fr
# https://www.supermood.com/
# https://www.swan.io/
# https://wgf.gg/
# https://computablefacts.com/
# http://hephaistos.ai/fr/home-francais/
# https://beclean.app
# https://www.the-artist-academy.fr/
# https://www.soireesympa.com
# https://www.pricinghub.net/
# https://recital.ai/
# https://trustpair.fr/
# https://www.sarbacane.com/
# https://www.happypal.fr/
# https://modjo.ai/
# http://www.brotherslovingbeer.com/
# https://badakan.com/
# https://www.joone.fr
# https://www.monsherif.com/
# https://www.ecodisplay.fr
# https://www.squiz.co/fr
# https://www.bet-on-you.com/
# https://monagil.fr/
# https://www.tradeinsur.com
# http://www.lagrandeourse.design
# https://quentin-pakiry.fr/
# https://www.theoutsiders.travel/
# https://omnegy.com
# https://hellosafe.ca/
# http://lafraise.co
# https://www.akuocoop.com/
# http://www.lesdechaines.fr
# https://www.prospectwith.com/
# https://profilpublic.fr/
# https://www.abtasty.com/
# http://deepclimb.io
# https://tikflow.co
# https://tickets-restaurant.com/
# Unexpected error: HTTPSConnectionPool(host='tickets-restaurant.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa17e3f710>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.lixo.tech
# https://forssea-robotics.fr/
# https://humans4help.com
# https://www.salesby.tech/
# https://hublo.com/landing
# http://www.lafourche.fr
# https://acinonyxweb.agency/fr/
# https://www.laconsignegreengo.com/
# https://popnight.fr
# https://www.magmatechnology.io/
# https://quandela.com/
# http://bellevilles.fr/
# https://bellman.immo/
# http://neofarm.fr/
# https://memo.bank
# http://www.preste.ai
# http://www.tandemz.io
# https://stockoss.com/
# https://fr.caregame.com
# https://www.ieva.io/
# https://www.voyageursdumonde.fr/voyage-sur-mesure
# https://pakko.fr
# https://farsem.com
# https://alertes-croquettes-tv.com/
# https://www.divenly.fr
# https://www.origin-labs.com/
# http://www.eatspossible.fr
# https://hautlescours.fr
# https://fealing.eu/
# https://lesbornees.com/le-projet
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# https://anakine.io/
# https://hydrocool.fr
# https://xlearn.fr/
# https://audi-on.com/
# https://www.tripitto.com/
# http://www.livejourney.com
# https://www.monlouetmoi.fr/
# https://looztick.fr/
# https://grannycharly.fr/
# https://www.olybe.com/
# https://www.panda-guide.fr/
# https://www.lizee.co/
# https://www.greenback.green/
# https://www.slatch.io/
# http://honing-biosciences.com/
# https://www.mces.gg/
# https://www.plume-app.co/
# https://www.adyouneed.com/
# https://ponicode.com/
# https://www.luko.eu/fr/
# https://neosilver.fr/
# https://linktr.ee/le_cryptopolitain
# http://www.adenlab.com
# https://www.kionect.com
# https://sommelierduparfum.com
# http://on-board.co
# https://www.flasheat.fr
# https://greenvillage.io/
# http://timees-coworking.fr
# https://www.darewise.com/
# http://www.ovinia.fr
# http://www.james-bang.com
# http://www.officeriders.com
# http://www.mylfruision.com
# https://www.twicpics.com/
# https://a-renover.com
# Unexpected error: HTTPSConnectionPool(host='a-renover.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.mad2moi.com
# https://welcome.clind.io/
# https://www.medireport.fr/
# http://www.lapatisserienumerique.com
# http://www.colocandyou.com
# https://www.magic4media.com
# http://www.finkey.fr/
# http://www.smart-company.fr
# https://surplace-aemporter.fr
# https://abilian.com/
# https://www.komin.io/
# https://beaubourg-avocats.fr/
# http://www.my-tennis.fr
# https://www.meridigital.com/
# https://simplelogin.io
# https://junior.mailo.com/
# https://www.storelift.co/
# https://www.cashbee.fr/
# https://www.modalova.fr/
# https://javelo.io/
# https://dimpl.io/
# https://placerenovation.fr/
# https://capté.fr
# https://www.watsonapp.fr
# https://www.clevermate.fr/
# https://www.klaxit.com/
# http://www.staffme.fr/
# https://portailduconseil.fr/
# http://www.smart-garant.com/
# https://monkvision.ai/
# https://www.alenvi.io/
# https://www.jow.fr/
# http://www.snouki.fr
# https://www.optionizr.com/
# https://wweeddoo.com/
# http://smylifeapp.com/
# https://www.hosman.co/
# https://geev.com/
# https://sharies.co/
# https://www.syment.com/
# https://www.side.co/fr
# https://www.d-arco-geotechnique.fr
# https://remotestash.fr/
# Unexpected error: HTTPSConnectionPool(host='remotestash.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'remotestash.fr' doesn't match '*.live-paas.net'",),))
# https://www.bonnieandcar.com/
# http://www.investirdanslancien.fr
# https://www.seald.io/fr
# http://www.colette.club
# https://www.idopia.com/
# http://www.francebarter.coop
# http://www.smooove.it
# https://www.quicktext.im
# https://zegarden.fr
# Unexpected error: HTTPSConnectionPool(host='zegarden.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1aa32588>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://tool-advisor.fr/
# https://proprilib.fr
# https://www.visitadom.fr/
# https://allolouis.com/
# https://www.donutleads.co/
# http://www.smart-services.com/
# http://www.blackt.io
# http://www.res-and-co.fr
# https://www.mailo.com/
# https://webcreacom.fr
# http://datascientest.com
# https://asksensors.com/fr/
# https://www.neocasesoftware.com/fr/
# http://www.excellentburger.com
# https://ideelgarden.com/
# https://www.elevo.fr/
# https://www.andjaro.com/
# https://d-aim.fr/
# https://www.articque.com/
# https://lokimo.ai
# https://lespepitestech.com/NA
# https://beev.co/
# https://www.zeway.com/
# https://www.dgtalstory.com/
# https://propryo.com
# https://www.inscreen.tv/
# http://www.kanopee-avocats.fr
# https://www.popkit.club/
# https://fecamp-services.com/
# https://www.neobrain.io/
# http://www.spliit.fr
# https://www.mercilaconciergerie.com
# https://happy-larry.com/
# https://entrepreneurs-covid19.com
# Unexpected error: HTTPSConnectionPool(host='entrepreneurs-covid19.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.conciergerie-numerique.fr/
# http://www.we-ynspire.com
# https://coachindemnites.com/
# https://thinkinsurtech.com/
# https://www.thewide.fr/coming-soon
# https://www.fooderise.com/
# https://www.energie-ip.com/fr/
# https://madely.co/
# Unexpected error: HTTPSConnectionPool(host='madely.co', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19267198>: Failed to establish a new connection: [Errno 111] Connection refused',))
# https://autoentrepreneur.net/
# https://www.ecovadis.com/
# https://place2swap.co/fr/
# https://clickandcare.fr/
# https://www.shippeo.com/fr
# https://lesnouveauxaffineurs.com/
# https://labombilla.fr
# https://adrenalead.com/
# https://cosmoz.bio/
# https://qualizy.app/fr/
# https://www.whilezero.fr
# https://findmy.domains
# https://www.cureety.com/
# https://www.chance.co/fr
# https://qilibri.fr/
# https://www.ergonimmo.com/
# http://www.zoomer.ai
# https://thechargingplace.eu/
# https://deconseil.com
# https://www.ouicsport.fr/
# https://www.djiminy.fr
# https://www.sciencescriminelles.fr/
# https://luluetkroy.fr
# https://www.heyflow.co/
# http://www.marluxparis.com
# https://ambuliz.com/
# https://watcha.fr/
# https://www.coverd.co/
# https://www.sportheroesgroup.com/
# Unexpected error: HTTPSConnectionPool(host='www.sportheroesgroup.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1931e0f0>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://www.amiwi.biz/
# https://www.transfertpro.com
# https://www.boks.app/
# https://www.vocads.com/
# https://auroremarket.fr/
# https://www.securkeys.com/
# https://manty.eu/
# https://coachapie.com
# http://www.loutillerie.com
# https://www.lab-event.com/
# https://up.law
# https://www.RoadMate.io
# https://www.mipise.com/fr
# http://www.kanmu.fr
# https://www.wellium.io/
# http://meltingvote.com
# https://www.adepem.com/
# https://www.protege-ecran.fr/
# http://www.vianova.io
# https://www.activcorner.com/
# https://www.littlecigogne.com/
# https://www.snapkey.fr/
# https://www.washmee.fr/
# https://www.goaland.fr/
# https://novabooking.fr/
# https://www.kaliz.fr
# https://www.picnic.paris
# https://www.equallywork.com/
# http://www.teamr.eu
# https://akur8-tech.com/
# https://www.stratow.com/
# https://www.flatchr.io/
# https://www.lanslot.app/
# https://www.linkyvet.com/
# http://www.fav-ikon.com
# https://cesoirsurseine.com/
# http://www.medquest.fr
# http://www.soclecollections.com
# https://redirection.io
# https://maia.ml-academy.org
# https://www.flowlity.com/
# https://digicrac.com/fr/
# https://www.avoloi.fr/
# https://stonly.com/
# http://www.wizaly.fr
# https://capitalkoala.com/
# https://berty.tech
# http://btobradio.tv/
# https://tzic.fr/
# https://connecting-food.com/
# https://www.a-biodesign.com/
# https://whelpy.io
# Unexpected error: HTTPSConnectionPool(host='whelpy.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18db60f0>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# http://www.beqom.com
# https://waamcosmetics.com/fr/
# https://qwarry.com/
# https://story-story.co/
# Unexpected error: HTTPSConnectionPool(host='story-story.co', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.tuteuralheure.fr
# http://www.businessfirst.io
# https://waltio.co
# https://www.eskimoz.fr/
# https://flexifleet.fr/
# https://www.pulse-origin.com/
# https://www.pictoaccess.fr/
# https://success-bay.com
# http://www.meraki.pm
# https://www.lesmiraculeux.com/
# https://www.weblib.fr/
# https://www.flui.city/home
# https://www.cettefamille.com/
# https://www.heyteam.com/fr
# https://uggy.io
# https://quiiet.co
# http://www.urbidesk.com
# https://www.skillcorner.com/
# https://shop.movensee.com/fr/
# https://home.seaverhorse.com/
# https://shapr.co/fr/bienvenue-sur-shapr/
# http://djs-avocats.com
# https://lemedecin.fr/
# http://www.rapidle.com
# https://www.vulkam.com/
# https://www.maatpharma.com/
# https://www.otodo.com/
# https://inato.com/
# https://www.kineis.com/
# https://www.salesdorado.com/
# Unexpected error: HTTPSConnectionPool(host='www.salesdorado.com', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'www.salesdorado.com' doesn't match either of '*.wpengine.com', 'wpengine.com'",),))
# https://www.askolga.fr/
# https://hawaii.fr/
# http://www.mileup.eu
# Unexpected error: HTTPSConnectionPool(host='www.mileup.eu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://petitbrunch.fr
# https://louiemedia.com/
# https://www.aviwest.com/
# https://siteflow.fr/
# https://www.we-link.io/
# https://powell-software.com/fr/
# https://edusign.fr
# https://www.cardiag.me
# https://josepho.io
# https://www.foodmeup.io/
# https://www.foodmeup.io/
# http://www.sanilea.fr
# http://www.cdip.com
# https://www.aptero.co/
# https://stafiz.com
# http://jamset.net
# https://hivebrite.com/
# https://www.bubble-globe.com
# http://upfactor.fr
# https://www.dashdoc.eu/fr/
# https://insurly.fr
# https://pentos.co
# http://www.stackast.com
# https://www.dpms.eu
# http://Diabolo.io
# https://tetu.com/
# https://www.harvestr.io/fr/
# https://immersivefactory.com/
# http://alchimistes.co/
# https://www.uniqueheritage.fr/fr/
# https://www.hardloop.fr/
# https://www.sensome.com/
# https://cardiologs.com/
# http://www.winwez.com
# https://www.monisnap.com/fr/
# http://www.captnboat.com
# https://supercreative.design/
# http://bleeker-st.com
# https://www.nomadplay.fr/
# Unexpected error: HTTPSConnectionPool(host='www.www.nomadplay.app', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19fc7e10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.pkvitality.com/fr/
# https://www.adux.com/
# https://www.datanewsletters.com
# http://www.feat-y.com
# https://elagage-paris.fr/
# https://getmayday.co
# https://www.capitainebarbu.fr/
# https://bone3d.com/
# http://livinparis.com/
# https://www.efficientip.com/
# http://www.cubeapps.co
# http://www.e-signum.fr
# https://www.getunlatch.com/fr/
# http://www.profitumconseil.com
# https://www.consultante-seo.paris/
# https://zelty.fr/
# https://laiguilleur.com/
# http://www.allsessions.fr
# https://jollymama.fr/
# http://www.inex-circular.com/
# https://store-mg.com
# https://enix.io/fr/
# http://www.mbandscott.com
# https://www.dynamo-cycling.com/
# https://www.citytaps.org/
# https://www.bigbagngo.com/
# http://flying-whales.com/fr
# https://www.humanoiddigital.net/
# Unexpected error: HTTPSConnectionPool(host='www.humanoiddigital.net', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a7f1e48>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://seyna.eu/fr/
# https://www.outsight.tech/
# https://www.mytraffic.io/en/
# https://yubo.live/en
# https://www.evermaps.com/
# https://intercloud.com/
# https://www.facebook.com/pg/wishbookworld/about/
# https://mabonnefee.com/
# https://makezu.io
# https://arbitryum.fr
# https://www.epc-champagne.com/
# https://maison-des-meches.fr
# http://cultivate.fr/
# http://bit.ly/38pOdDA
# http://bit.ly/2PEj8Du
# http://bit.ly/35caoLj
# http://bit.ly/35mF3Gd
# http://bit.ly/36Ag2HN
# https://len.bo
# Unexpected error: HTTPSConnectionPool(host='len.bo', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1aaee710>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://hegid.com
# http://bit.ly/2PckaYl
# https://www.lerougefrancais.com/
# https://www.lesripeurs.com/
# http://r-pur.com
# http://upfactor.fr/
# https://fr.ankorstore.com/
# https://www.gitguardian.com/
# https://www.odero.com
# https://www.abyssale.com
# https://klox.fr/
# https://la-ruche.net/
# https://moodwork.co/site
# http://www.virgil.fr/
# https://www.woo.paris/
# http://LEAVY.CO
# https://www.sewan.fr/
# http://www.splandeed.com
# https://www.ethikdo.co/
# https://shop.vivlab.com
# http://www.netnow.fr
# https://dailylive.co
# https://www.partners-finances.fr/
# https://www.perfony.com/fr/
# http://velyvelo.com/
# https://www.datamechanics.co/
# https://www.loom.fr/
# https://www.snapshift.co/
# https://www.coucoo.com/
# https://predictice.com/
# https://lalilo.com/
# https://www.biolog-id.com/fr/
# https://tissium.com/
# https://www.miloe-sante.com/
# http://modeo.ai
# http://www.wibbitz.com/fr
# https://www.easydigitalkey.com
# http://sipios.com
# http://www.oopet.io
# https://www.matchoffice.fr/
# https://www.pandat.fr/
# https://wittyfit.com/en/
# https://www.go-ee.com/go-ee/
# https://getmansa.com
# http://acticor-biotech.com
# https://concilium.digital/
# https://publithings.com
# https://www.yavin.com/
# https://sayya.fr/
# https://hidden.market/
# https://libeo.io/
# https://kardinal.ai/fr/
# http://www.royalti.fr
# http://www.laplace-fintech.com/
# https://www.happy.property
# Unexpected error: HTTPSConnectionPool(host='www.happy.property', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19e8df60>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://vitality.gg/
# http://www.studiomatic.co
# https://www.talkspirit.com/fr/
# https://risinguparis.com
# https://www.mes-allocs.fr
# https://www.popframe.fr/
# http://oprotect.com
# https://beeldi.com/
# https://doohit.fr/
# https://www.brut.media/
# https://www.spotimplant.com
# https://fiduce.fr
# http://www.adequacy.app
# https://www.makko.fr
# https://licornesociety.com/
# https://doyouno.com/professionals/search
# http://DROON.IO
# https://fiduce.fr/
# http://www.scallog.com/
# http://www.digimium.com
# https://vivadata.org
# https://www.ddays.app/
# https://www.sleepingmoney.com
# https://www.uneeti.com
# https://www.bigupvideo.com
# http://www.aqemia.com/
# https://www.posos.fr/
# https://www.konverso.ai/
# https://strapi.io/
# https://www.uptime.ac/
# https://madbox.io/
# https://www.uptoo.fr
# https://www.mobeep.app
# https://www.otheroffice.fr
# https://crushonapp.com/
# http://www.mooncard.co
# https://ohmy.bio/
# http://www.framesdealer.com
# https://www.bizao.com/
# http://www.medusims.com
# http://www.packetai.co/
# https://paperplane-seo.com
# Unexpected error: HTTPSConnectionPool(host='paperplane-seo.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a116e48>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.anticafe.eu
# https://www.leadadvisor.fr/
# https://www.axionable.com/
# https://colivme.com/fr
# http://www.wifit.media
# https://www.steolo.com
# https://www.numamentors.co/
# https://www.eventdrive.com/
# https://www.frequens.com
# https://ip-transfer.com/
# https://sublissi.me
# https://cuure.co/
# https://flitdesk.com/
# https://pickyourskills.com/
# https://maze.design/
# https://www.cocoon-space.com/
# https://www.salesapps.io/en/
# https://anotherbrain.ai/
# https://slice.club/
# http://www.welcol.io
# https://cyclopowerfactory.com
# http://devis-mutuelle-france.fr/
# https://www.mutuelle-comparateur-sante.com/
# Unexpected error: ('Connection aborted.', OSError(0, 'Error'))
# https://www.annonces-legales.org
# http://www.createrocks.com
# http://www.theideall.com
# https://www.sevessence.com
# https://utip.io/
# https://viibe.co/
# https://incepto-medical.com/
# https://openclassrooms.com/fr/
# https://www.blade-group.com/en
# https://www.voodoo.io/
# https://www.hr-path.com/fr/
# https://www.frichti.co/
# https://www.heypongo.com/
# https://www.nextstation.com/fr
# https://www.leeto.co/
# https://liberkeys.com/
# https://www.kaiko.com/
# https://www.agorapulse.com/
# http://bartoc.co
# https://abcdigitaltouch.fr
# https://www.newbizconsulting.fr
# http://www.hashtagavocats.com
# https://www.entoureo.fr
# http://www.sextantfrance.fr
# https://www.dreamcatcher-sales.com
# http://www.lewisbnb.fr
# http://www.reunio.fr
# https://zyl.ai/
# Unexpected error: HTTPSConnectionPool(host='zyl.ai', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19e85518>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://urgencedocteurs.com/fr/
# https://eatcala.com/
# http://www.nukk.ai/
# https://bliink.io/
# https://www.hellopret.fr/
# https://livestorm.co/fr/
# https://beop.io/
# https://www.inotrem.com/
# https://www.jobteaser.com/fr
# https://www.wattsplan.com/
# http://www.vicinity-app.com
# https://certitag.com/
# http://www.NextperienceTech.com
# Unexpected error: HTTPConnectionPool(host='www.nextperiencetech.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1a4adf98>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://yakaz.fr
# http://www.hellohome.fr
# https://rootze.com/
# http://www.milvue.com
# https://en.ohmycream.com/
# https://www.galliaparis.com/
# https://vivoka.com/fr/
# https://www.heuritech.com/
# https://www.alterea.fr/
# https://checkmyguest.fr/
# https://www.m2i-lifesciences.com/
# http://hifibio.com/
# https://livequestion.com/
# https://visite360pro.com
# https://tresorio.com/
# https://workin.space
# https://www.giftcampaign.fr/
# https://www.onbrane.com/
# https://www.ds-digital.us
# https://www.lavoirmoderne.com/
# http://www.continuumplus.net/
# https://www.kactus.com/
# https://www.flatlooker.com/
# https://www.universign.com/fr/
# https://www.thebureau.club/fr/home/
# https://www.hivency.com/fr/
# https://bealink.io
# https://www.chaintrust.io/
# http://www.bruce.work
# https://picandpick.com/
# http://www.simundia.com/
# https://www.captainwallet.com/
# https://peoplespheres.fr
# https://www.guanxi-invest.com/
# https://mailmeteor.com
# http://www.fideliz.io
# https://greenticketapp.com/fr/
# Unexpected error: HTTPSConnectionPool(host='greenticketapp.com', port=443): Max retries exceeded with url: /fr/ (Caused by SSLError(CertificateError("hostname 'greenticketapp.com' doesn't match either of 'cluster021.hosting.ovh.net', 'www.cluster021.hosting.ovh.net'",),))
# http://novelab.net/fr/
# http://topovideo.com/
# https://www.e2time.com/fr/accueil/
# https://salvum.org/
# https://www.smartvr-studio.com/
# http://www.dahersoftware.com
# https://nouga.fr/
# https://www.alz-pharma.com/
# https://pinsmart.fr/
# Unexpected error: HTTPSConnectionPool(host='pinsmart.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1835deb8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.yokitup.com
# https://wayup.studio
# Unexpected error: HTTPSConnectionPool(host='wayup.studio', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1835d780>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.thesolehouse.com/app/cote-officielle-des-sneakers
# http://www.bebop.cab
# https://www.krooga.fr/
# https://theoriq.com/fr
# http://www.innoscape.com
# https://www.myminutetrip.com/
# https://spartera.network
# Unexpected error: HTTPSConnectionPool(host='spartera.network', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a182b38>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://victor-habitat.com
# https://mindee.co/
# https://inthememory.com/
# https://www.couriier.com/
# https://eternoscorp.com
# http://freelancenation.fr/
# https://ecotree.green/
# https://www.top-rgpd.com
# https://www.shareplace.com/fr/
# http://assurance-decennale-pas-chere.fr
# https://www.7-shapes.com/
# https://www.smile.eu/fr
# https://www.escapad.io/
# https://www.spotlag.com/
# https://nouvelle-recrue.fr
# Unexpected error: HTTPSConnectionPool(host='nouvelle-recrue.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a3fa470>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://thetotem.co
# https://www.avizio.fr/
# https://sembuddy.com
# https://www.bazimo.fr/
# https://www.mon-cdi.fr/
# http://www.absiskey.com/
# https://carte-soshop-club.myshopify.com/
# https://www.tribvn-hc.com/fr/
# https://yseop.com/fr/
# https://www.teaminside.fr/
# https://www.traxens.com/
# http://www.puredatasource.io
# https://www.weekendr.eu/
# https://getalma.eu/
# https://www.karamel.cool/
# https://www.filae.com/
# https://www.wixicode.fr
# https://www.papayoux.com
# http://www.latexb.io
# http://www.helloharel.com
# https://vitadx.com/
# https://www.spacelephant.org/fr/
# https://ffly4u.com/
# https://pubstack.io/
# https://www.parkingmap.fr/
# https://regenlife.com/fr/accueil/
# http://www.microphyt.eu/
# https://empowill.com
# https://www.lifen.fr/
# https://www.holyowly.fr/
# https://phantombuster.com/
# https://copees.com/
# https://www.cozycozy.com/fr
# https://vivlab.com
# http://dcbrain.com/
# https://www.latelierdescanapes.com/
# https://logora.fr/
# https://www.wefight.co/fr/accueil-2/
# https://wakeo.co/fr/
# https://www.notiloplus.com/
# http://www.energy-observer.org/
# https://popvalet.com/
# https://www.innovorder.fr/
# https://immersiveexperience.fr/
# http://www.ideetangible.com
# https://www.myweekendforyou.com/
# https://www.naister.com/
# https://www.cood.fr/
# https://www.teepik.com/fr/
# https://www.hiflowsuite.com/fr
# https://www.joliefamily.fr/
# https://www.proptechinvest.immo/
# Unexpected error: HTTPSConnectionPool(host='www.proptechinvest.immo', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a9e1828>: Failed to establish a new connection: [Errno 111] Connection refused',))
# https://www.hapaxlyon.com/fr/votre-sante
# https://dilepix.com/
# https://www.newsbridge.io/
# https://www.justeatemps.com/
# https://www.expanders.fr/
# https://www.artifakt.io/
# https://www.foodles.co/
# https://fr.motherland-store.com
# Unexpected error: HTTPSConnectionPool(host='fr.motherland-store.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a8f6080>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://fr.weadvocacy.com/
# https://www.citima.co
# http://pepsia.com/
# https://unkle.fr
# https://www.letempsduthe.fr
# https://www.nowadaysagency.com/
# https://www.charitips.com
# https://www.triazur.com/fr/
# http://www.nutriearth.fr/
# https://www.reparcar.fr/
# https://www.dessintey.com/
# https://www.lesopticiensmobiles.com/
# https://www.tilkal.com/
# https://home.sinaaps.com/
# Unexpected error: HTTPSConnectionPool(host='home.sinaaps.com', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'home.sinaaps.com' doesn't match either of 'shortener.secureserver.net', 'www.shortener.secureserver.net'",),))
# https://www.cleverconnect.com/
# https://www.bleckwen.ai/
# https://ekim.fr/
# https://www.bioserenity.com/
# https://www.wifirst.com/
# http://www.eckometrics.com
# https://goshaba.com/
# https://www.kiflo.com/
# http://datategy.net/fr/accueil/
# https://www.tudigo.co/
# https://www.6lab.com/
# https://jusmundi.com/fr/
# http://www.icaros.fr
# http://www.roadbook.care
# https://thetribe.io/
# https://borea.dental/
# https://lespepitestech.com/dashboard/search
# https://www.hgct-europe.fr/
# https://www.dualthegame.com/fr/novaquark/
# https://www.finexkap.com/
# https://www.vadesecure.com/fr/
# https://www.coover.fr/
# https://startupcrm.fr
# https://www.beneficia.fr
# https://www.takeameal.fr
# https://www.leclan.io/
# http://upslide.net
# https://karma.life/
# http://www.lotaemi.com
# https://kifwatimmo.com
# https://www.sky-indemnity.fr/newsfeed/service-enterprise/
# https://www.citalid.com/
# https://tridekone.com/
# https://involve.paris
# https://kard.eu/
# https://mobeelity.io/
# https://www.foxnot.com/
# https://www.digitim.fr/
# https://fr.ivalua.com/
# http://www.wever.fr/
# http://www.magadi.fr
# https://www.moodze.me
# http://www.klap.io/
# https://www.everent.io/
# Unexpected error: HTTPSConnectionPool(host='www.everent.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a9ee780>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.pagachey.com
# https://www.movinsmart.com/
# https://moneway.com/
# https://www.bcdiploma.com/index-fr.html
# https://www.waoup.com/
# https://www.mindsay.com/
# http://geoffrey-pin.fr
# https://enless-wireless.com/fr/
# https://www.boxpapymamy.com
# https://www.moplyz.com
# https://turnkeyledger.com/index.html
# Unexpected error: HTTPSConnectionPool(host='turnkeyledger.com', port=443): Max retries exceeded with url: /index.html (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa190b29b0>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# https://meilleuredomiciliation.fr/
# http://www.captaindoc.fr
# https://www.sweevana.com
# http://www.boundlessdigital.fr
# https://www.charles.co/
# https://www.hellojam.fr/
# https://www.whereyoulove.com/
# https://www.whereyoulove.com/
# https://newheat.fr/
# https://www.indigoweel.com/
# https://sim-and-cure.com/language/fr/accueil
# Unexpected error: HTTPSConnectionPool(host='sim-and-cure.com', port=443): Max retries exceeded with url: /language/fr/accueil (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.azurdrones.com/fr/
# https://www.simplis.fr/
# https://moovone.eu
# https://www.deuxiemeavis.fr/
# https://www.pricemoov.com/
# https://www.garantme.fr/
# https://www.manzalab.com/
# https://www.cautioneo.com/
# http://toktokdoc.com/
# https://www.pixpay.fr/
# https://www.coleen-france.com/fr/
# https://www.thegrowthlist.co/
# https://whyse.co/
# https://www.wiztopic.com/fr/
# https://www.epc-champagne.com/
# http://www.nawatechnologies.com/
# https://www.ecojoko.com/
# https://www.anamnese.me/home/
# https://www.visiblepatient.com/fr/
# http://dnascript.co/
# https://sorare.com/
# https://www.proprioo.fr/
# http://picso.io
# https://www.odaseva.com/
# https://otakam.fr/
# https://www.nomalab.com/
# https://monsieurgourmand.com/
# https://www.bam-karaokebox.com/
# https://carvivocontact.com/
# http://www.coservit.com
# https://www.secret-saas.com/
# Unexpected error: HTTPSConnectionPool(host='www.secret-saas.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18afa390>: Failed to establish a new connection: [Errno 111] Connection refused',))
# http://www.spliiit.com
# https://monbanquet.fr/
# https://wemaintain.com/fr
# https://allohouston.fr
# https://www.gofer.fr/
# https://goodsid.io/
# https://etimoc.com/
# https://www.blancreme.com/
# https://sky-real.com/
# http://www.popinthecity.com
# https://www.pepette.co/
# https://www.soonvibes.com
# https://www.pachamama-handcraft.com/fr/accueil/
# https://www.lestricolores.fr/
# https://dessinetonmeuble.fr/
# https://www.tuttis.fr/
# https://www.keeneyetechnologies.com/en/
# https://www.lagentlefactory.com/
# https://www.tactical-adventures.com/
# https://mychatbotagency.com/
# Unexpected error: HTTPSConnectionPool(host='mychatbotagency.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1ab37e10>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# https://meilleurspromoteurs.immo
# https://www.studentpop.fr/
# https://fr.360learning.com/
# https://alsid.com/fr
# https://www.octopulse.io/fr/
# https://www.oppn.co
# https://greenmove.fr/
# https://www.smartloc.fr
# https://www.otonomy-aviation.com/
# http://www.pm-up.fr
# http://www.evaltonbiz.fr
# https://www.getmyre.com
# https://www.kannelle.io/
# https://webotit.ai/
# https://lesboosteuses.com/
# http://nhtheraguix.com/
# https://bloomin.digital/
# https://www.kokoon.paris
# https://simplon.co/
# http://www.intent-technologies.eu/
# http://www.agora.place
# http://didacteec.com
# https://www.moonshot-internet.com/fr/
# https://www.universal-glasses.com
# https://hibruno.com
# http://www.abistart.com
# https://holomaton.fr/
# https://hologramme.org
# http://www.lightingseo.com/fr/
# https://www.addevmaterials.fr/
# Unexpected error: HTTPSConnectionPool(host='www.addevmaterials.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.gwenneg.bzh/fr
# https://www.nestwave.com/
# http://www.upela.com
# https://www.homerez.fr/
# https://www.quidol.fr/
# https://www.izifamily.com/
# https://www.globethik.com
# http://fundraising.bplatform.fr
# https://moralscore.org
# https://www.mymerrys.com/
# Unexpected error: HTTPSConnectionPool(host='www.mymerrys.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1ab409b0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# https://wipe.city/
# http://exdone.fr
# Unexpected error: 'content'
# http://www.location-vacances-express.com
# https://www.edmond-art.com/
# Unexpected error: HTTPSConnectionPool(host='www.edmond-art.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18f2f4e0>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://www.sericyne.fr/fr/sericyne.html
# https://www.zaion.ai
# https://www.manomano.fr/
# https://www.calimed-sante.fr/
# http://bit.ly/2Il6QxV
# https://www.tipdigger.com/
# Unexpected error: HTTPSConnectionPool(host='www.tipdigger.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa17e62f28>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://synapse-medicine.com/
# https://www.hesus.eu/fr/accueil/
# https://dental-monitoring.com/
# https://drmilou.fr/
# https://www.coworkees.com/
# http://athemisassocies.fr/
# Unexpected error: HTTPConnectionPool(host='athemisassocies.fr', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18b6a160>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.patchaia.com
# https://www.reality.fr/
# https://direct-market.fr/
# https://emkipop.fr/
# https://unistellaroptics.com/
# https://www.cycloid.io/
# https://www.wgf.gg/login
# https://cosmian.com/
# http://www.unigolfusa.com
# http://www.bevipe.com
# https://cassius.fr/
# http://www.owlie.xyz
# http://swapbook.fr
# https://tripartie.com/
# https://www.misakey.com/
# https://cocoonr.fr/
# http://www.fisio.fr
# https://www.mycvfactory.com
# https://www.inasoft.fr/
# https://www.avecvotrelogo.fr/
# https://chargesoptim.com
# Unexpected error: HTTPSConnectionPool(host='chargesoptim.com', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'chargesoptim.com' doesn't match either of 'cluster027.hosting.ovh.net', 'www.cluster027.hosting.ovh.net'",),))
# https://hyperlex.ai
# https://www.bigblue.co/
# http://www.rgl-research.com
# https://gamestream.biz/
# https://www.oslo.fr/
# https://myjoliecandle.com/fr/
# https://www.synintra.com/
# https://www.happytal.com/
# https://www.padoa.fr/
# https://www.shift-technology.com/
# https://www.homeland.immo/
# http://smartglobalprivacy.com
# https://corp.dxomark.com/
# http://leocare.fr
# http://www.vivaling.com
# https://siga.care/
# https://www.tekyn.com/
# https://www.muzeek.com/
# https://www.go-klevr.fr/
# https://reality-academy.fr/
# https://gingalab.com/
# https://www.forseepower.com/fr
# https://trusk.com/
# https://pitchboy.sc/
# https://kobusapp.com/
# https://goodsh.it/
# https://tize-app.com
# Unexpected error: HTTPSConnectionPool(host='tize-app.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a711f28>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# http://www.abcsr-performance.com/
# https://www.actronika.com/
# http://gamersorigin.com/fr/
# https://www.chefing.fr/
# https://www.loueragile.fr/
# https://www.antescofo.com/fr/
# https://sybel.co/
# https://www.poulehouse.fr/
# https://www.typology.com/
# https://livecolonies.com/home-fr
# https://register.simplysurfers.com/fr
# https://www.pygmento.com/fr/
# https://bonjourautoentrepreneur.fr
# https://yuka.io/
# https://www.captain-drive.com/
# https://yemp.co
# https://www.cocoom.com/
# https://www.majelan.com/
# https://www.govirtuo.com/fr
# https://www.malt.fr/
# https://www.japhy.fr/
# https://www.ergosup.com/
# https://descartesunderwriting.com/
# http://my-retail-box.com/
# https://www.thegreendata.com/
# https://www.statum.fr/
# http://www.crossyjob.com
# Unexpected error: HTTPConnectionPool(host='www.crossyjob.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1a652128>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.granada-kyc.com
# https://www.matcha.wine/fr/
# https://peppr.fr
# https://galanck.com/
# https://www.monbuilding.com/fr
# https://www.igoseo.fr/
# https://www.paytrip.fr/
# https://www.ambler.fr/
# https://web.convelio.com/home
# https://www.fleeteq.com/
# https://timetonic.com/
# https://www.agriloops.com/
# https://ourco.io/
# Unexpected error: HTTPSConnectionPool(host='ourco.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18f29c50>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://www.embleema.com/fr/
# http://www.aelg-consulting.com
# https://www.aureolebox.fr
# https://deepomatic.com/fr/
# http://afyren.com/
# https://www.nomad.immo/
# https://pro.waage.fr/
# https://www.leciseau.fr/
# http://valetdepique.fr
# https://www.qweekle.com
# Unexpected error: HTTPSConnectionPool(host='www.qweekle.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.angus.ai
# Unexpected error: HTTPSConnectionPool(host='www.angus.ai', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.larinella.com
# Unexpected error: ('Connection aborted.', OSError(0, 'Error'))
# http://SMOKEY-PARIS.COM
# https://www.rocambole.io/
# https://www.espace-ombrage.com
# http://www.jourj.fr
# https://www.overcoaching.fr
# https://www.gulplug.fr/
# https://www.betondirect.fr/
# https://mywah.fr
# http://upflow.io/fr-fr/
# http://www.keradom.fr
# https://www.waage.fr/
# https://aidealapersonne.fr/
# https://www.vintagerides.com/voyage-moto/amerique-du-sud-perou/
# http://theschoolab.com/
# https://www.allostand.com
# http://www.hiboo.io
# https://www.ovrsea.com/
# http://therapanacea.eu/
# http://www.diota.com/index.php/fr/
# https://www.combiencoutemonsiteinternet.com/
# http://www.homeys.io
# https://www.combigo.com
# https://www.easypartner.fr/
# https://www.singulart.com/fr/landing
# http://mikiz.eu
# https://www.habiliv.fr
# https://www.adresse.paris/
# https://www.nomdunepatte.com
# https://www.onepark.fr/
# http://www.addworking.com/
# http://www.myamusebox.com
# https://outils-webmarketing.com
# https://ideel.io
# https://ngbiotech.com/
# https://www.delitoon.com/
# http://www.lumiere-et-deco.com
# https://mes-charades.com
# http://www.cideo-engineering.com
# http://www.tolance.com
# http://www.trouvetavoie.io
# https://fairmakers.com/
# https://www.swile.co/
# http://www.gipsy-baby.com
# http://www.go-aos.io
# https://lynx-r.com
# https://www.carjager.com/
# https://www.qape.fr/
# https://shop.beendhi.com/
# https://www.dejalu.fr/
# https://vizeer.io
# https://www.bienpreter.com
# https://www.bigmoustache.com/
# http://www.seeketing.fr
# https://www.hellowatt.fr/
# https://smartkeyword.io/
# http://www.useitcloud.com
# https://www.monsieurbarbier.com/
# http://leviagermutualise.fr/
# http://nossa-acai.com/fr/nossa/
# https://www.livsty.fr/
# https://1988films.tv/
# http://pikorini.com
# Unexpected error: HTTPConnectionPool(host='pikorini.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18ea93c8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://fmrdesigner.com/
# https://murfy.fr
# http://www.shapin.tv
# https://www.coinhouse.com
# http://www.3dtdm.net
# https://www.rainette-shop.com/
# https://www.laboiteachampignons.com/
# https://paris.ugomap.fr
# https://madeinfrancebox.com/
# Unexpected error: HTTPSConnectionPool(host='madeinfrancebox.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://solarbrother.com
# http://www.udiz.io
# https://imagine-communication.fr
# https://www.notre-notaire.fr/
# http://www.lecloset.fr
# https://www.courbet.com
# http://shokly.com
# https://www.nomad.immo
# https://www.lanavette.co/
# https://www.autorigin.com/
# https://www.lamallefrancaise.com
# http://www.funkyveggie.fr
# http://www.medium.club
# Unexpected error: HTTPConnectionPool(host='www.medium.club', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18d6f470>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.gorille-cycles.fr
# https://designerbox.com
# http://www.QuatreEpingles.fr
# Unexpected error: HTTPSConnectionPool(host='www.quatreepingles.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://firsty.co
# http://walleriana.com
# https://www.lbf-biere.fr/
# http://www.robobox.fr
# http://www.lastable.mobi
# https://www.blog-immo-neuf.com/
# https://fr.perus.co/
# https://app.studio
# https://deux.io/
# http://bilansanteinternational.com/
# https://www.shaapes.fr/
# Unexpected error: HTTPSConnectionPool(host='www.shaapes.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1ad687b8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://pixelme.me/
# http://www.cityinmybag.com
# https://www.roadstr.fr
# http://www.koakoa.fr
# https://www.trouver-un-transporteur.com/
# http://www.lebonchien.fr
# http://lesnouveauxfromagers.fr/
# http://www.renforconseil.fr
# https://www.dretechinsdustry.com/
# Unexpected error: HTTPSConnectionPool(host='www.dretechinsdustry.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa192d1048>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.lechefenbox.com
# http://www.bmaker.fr
# http://www.tecwec-networks.eu
# http://www.xxe.fr
# http://www.maplab.green
# https://www.emailplanner.io
# Unexpected error: HTTPSConnectionPool(host='www.emailplanner.io', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'www.emailplanner.io' doesn't match either of '*.dynadot.com', 'dynadot.com'",),))
# https://musicworldmedia.com
# http://next-mind.com/
# http://carthera.eu/fr/
# http://earlymetrics.com/
# http://www.map-patho.com
# https://bubblemeeting.net
# https://fiitli.com/
# http://www.keplerk.com
# Unexpected error: HTTPConnectionPool(host='www.keplerk.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1a322b00>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://www.pousse.studio/
# http://www.movinmotion.com
# https://www.location-etudiant.fr/
# https://www.lepaveparisien.com/
# https://kipli.com
# https://agricool.co/
# https://www.combiencoutemonapp.com
# http://www.tipikk.com
# http://www.sinaxia.fr
# http://www.auum.fr
# http://www.frenchbureau.com/fr
# http://www.askeet.io
# https://www.purevpn.fr/achetez
# http://www.madamepee.com
# http://www.herve.io
# https://studiobolide.com
# http://www.lawgarithm.net
# https://www.ojm-diffusion.com/
# http://www.synchronized.tv/
# http://innovafeed.com/index-fr.html
# https://www.brocantelab.com/
# https://www.oyst.com/
# Unexpected error: HTTPSConnectionPool(host='www.oyst.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1abb74e0>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# https://lamokabox.com/
# http://www.numeryx.fr
# https://www.theassistant.com/fr/
# http://datagram.ai
# http://azmed.co
# https://rubypayeur.com/
# http://www.htheoria.com
# https://www.booper.fr/
# http://www.cadic-services.com
# https://ignition-program.com/
# https://www.crosstalent.eu/fr/
# https://www.stillatechnologies.com/
# http://www.dataimpact.fr/
# http://www.greenliv.fr
# http://www.khdemti.com
# http://www.joovence.com
# https://www.smallbusinessact.com
# http://www.libon.com
# https://www.libizi.fr/
# http://www.unowhy.com
# http://www.bbbb.com
# http://www.zenmoov.com
# https://predilex.io/
# https://oppidumsecurity.com/
# https://www.pilgo.com/
# https://www.lagence123.com
# https://www.edgewhere.fr/
# https://www.melty.fr/
# https://mindout.fr/
# https://www.wearelocal.ai
# http://www.sublimeprod.com/startups
# http://www.kultizit.com
# http://www.insideall.fr
# http://www.skydeals.shop
# https://isars.company
# http://reussirsesobjectifs.strikingly.com/
# https://www.geoxilia.com
# https://www.talentsoft.fr/
# https://www.zoov.eu/
# http://www.adionics.com/en/
# https://www.bigbee.fr/
# Unexpected error: HTTPSConnectionPool(host='www.bigbee.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa196c49e8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://pathtime.fr
# https://www.toclic.fr
# http://www.humindschool.com
# https://cap-collectif.com
# https://ineat-group.com/
# https://www.yesweshare.fr
# https://www.kaviar.app/
# https://odysway.com/
# https://gaston.tel
# https://pabete.com/
# http://www.aulu.fr
# http://stanley-robotics.com
# http://www.contentside.com
# https://www.invectys.com/
# http://www.oncrawl.com
# https://www.mistertemp.com/
# http://www.nodata.co
# https://www.guestready.com/fr-fr/conciergerie-airbnb-paris/
# https://bonanza.paris
# https://www.reezocar.com/
# http://www.bioxegy.com
# http://www.loginchinese.com/
# Unexpected error: HTTPConnectionPool(host='www.loginchinese.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18b18cf8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.ethicadvisor.org
# https://www.vegea.com/
# https://www.lavieduvin.fr
# https://www.reprizentreprise.fr/
# Unexpected error: HTTPSConnectionPool(host='www.reprizentreprise.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://devenir-auto-entrepreneur.net/
# Unexpected error: HTTPSConnectionPool(host='devenir-auto-entrepreneur.net', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a3153c8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.teeptrak.com/fr/teeptrakaccueil
# https://www.alveolelab.com/fr/
# https://www.metronlab.com/fr/accueil
# https://www.docker.com/
# http://www.oxypharm.net
# https://www.baloon.ci/
# https://www.vuac.fr/
# http://pagexl.com
# http://mooveby.com
# https://www.lunc.fr/
# Unexpected error: HTTPSConnectionPool(host='www.lunc.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://voxpay.ai
# https://www.meero.com/en/
# https://fastory.io/
# http://www.noemiconseil.fr
# https://socialgrowth.fr/
# Unexpected error: HTTPSConnectionPool(host='socialgrowth.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1914cc88>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# ...
# http://www.lafabriquedunet.fr/
# http://www.painpon.com/
# Unexpected error: HTTPConnectionPool(host='www.painpon.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18b4cc18>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.tictoque.com/
# Unexpected error: HTTPSConnectionPool(host='www.tictoque.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18b4ce10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.ohmyguest.fr
# Unexpected error: HTTPConnectionPool(host='www.ohmyguest.fr', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18b4cc50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://studizen.co
# http://www.citodi.com
# http://heros-pour-de-vrai.com/
# http://www.21HEURES.fr
# https://www.talentclub.io/
# Unexpected error: HTTPSConnectionPool(host='www.talentclub.io', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.ateliers-draft.com/
# https://emailhunter.co/
# http://sunnychairs.fr/
# Unexpected error: HTTPConnectionPool(host='sunnychairs.fr', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19fda2b0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.uslide.io/
# Unexpected error: HTTPSConnectionPool(host='www.uslide.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19fdaf28>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.skytea.fr
# http://peekee.me
# Unexpected error: HTTPConnectionPool(host='peekee.me', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19fdabe0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.kenweego.com/fr
# Unexpected error: HTTPSConnectionPool(host='www.kenweego.com', port=443): Max retries exceeded with url: /fr (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.blacklistic.fr/application-mobile-blacklistic-19.html
# http://captaincontrat.com/
# http://www.clothetomeapp.com
# http://www.reserverunbar.fr
# http://www.hrcareers.fr
# http://www.mycuistot.com
# http://cremedelacreme.io
# http://www.cyborg-vegetal.fr/
# http://www.beekast.com
# https://accueil.payfacile.com
# http://www.blacklistic.fr/application-mobile-blacklistic-19.html
# http://www.kameleoon.com/
# http://www.actimeety.com
# http://www.leschasseursdeprix.com
# http://www.lunii.fr
# http://www.cyclez.fr
# https://www.papernest.com/
# http://www.simply-senior.com
# Unexpected error: HTTPSConnectionPool(host='www.epicuria.net', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'www.epicuria.net' doesn't match either of 'cluster010.hosting.ovh.net', 'www.cluster010.hosting.ovh.net'",),))
# http://www.bpifrance-lehub.fr/
# http://www.wedefi.com
# http://allomarcel.com/
# https://commoprices.com
# https://ondemand.lewagon.org/gift
# http://apple.co/1DqXPdn
# https://www.soyezbcbg.com
# http://aircall.io
# http://wisembly.com/fr/
# Unexpected error: HTTPSConnectionPool(host='www.wisembly.com', port=443): Max retries exceeded with url: /fr/ (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.myhoper.com
# http://www.mirakl.com/
# https://www.octobat.com
# https://www.qwant.com
# https://www.makeupline.com/
# Unexpected error: HTTPSConnectionPool(host='www.makeupline.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a0306a0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# http://www.axeleo.com/
# https://stootie.com/
# http://www.keecker.com/
# Unexpected error: HTTPSConnectionPool(host='www.keecker.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.vente2site.fr
# http://www.fifty-five.fr/
# http://www.dashlane.com/fr/
# http://misterjack.co
# http://www.wistiki.com/1.aspx
# http://www.bizecho.com
# http://www.ubudu.com/
# https://appsto.re/fr/qRJtN.i
# http://juritravail.com
# http://myownartgallery.com/
# Unexpected error: Exceeded 30 redirects.
# https://www.onoff.fr/
# http://www.easyproprietaire.com
# Unexpected error: HTTPConnectionPool(host='easyproprietaire.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1aaf3c50>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://homengo.com
# Unexpected error: HTTPSConnectionPool(host='homengo.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.inspeer.me/
# http://bunkrapp.com/
# http://www.karry-me.com
# http://zelip.co/
# http://www.youboox.fr/
# http://www.happhapp.com/
# http://www.amogado.com
# http://www.devispresto.com/
# http://bit.ly/iplayduo1
# https://www.rdvmedicaux.com
# http://www.wengo.fr
# http://www.midipile.com
# https://gorgias.io/
# http://unimersiv.com
# http://padambus.com/
# http://www.archionline.com/
# https://www.keldoc.com/
# http://www.mymajordhome.net/
# Unexpected error: HTTPConnectionPool(host='www.mymajordhome.net', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1ac90c88>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.humancoders.com/
# http://www.mooltibox.com
# http://apple.co/1DoTPKF
# http://www.heyythere.com
# http://www.iskn.co/fr
# https://www.datananas.com
# https://infinit.io/
# Unexpected error: HTTPSConnectionPool(host='infinit.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a7b9f60>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://www.capitainetrain.com/
# http://www.laboiteaservices.com
# http://www.creads.fr/
# http://www.lepetitballon.com/
# http://www.speedphoning.com
# http://www.404works.com
# https://www.bird-office.com/
# https://racontr.com
# https://www.clacdesdoigts.com/
# http://lespepitestech.com/tinder-des-startups-french-tech
# http://www.game2game.com
# http://www.vivanoda.fr/
# http://www.fasterize.com/fr/
# http://www.withings.com/fr/withings-activite.html
# http://www.ecobill.fr
# http://adways-studio.com/fr/
# http://www.archos.com/fr/products/objects/cself/amb/index.html
# http://fr.bnbsitter.com/
# http://www.heavym.net/fr/
# Unexpected error: HTTPSConnectionPool(host='heavym.net', port=443): Max retries exceeded with url: /fr/ (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# https://www.clickandboat.com
# https://www.welkeys.com/
# http://www.driiveme.com
# http://www.dayuse-hotels.com/fr/FR/
# http://owlperception.com/
# Unexpected error: HTTPConnectionPool(host='owlperception.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa190b56d8>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# http://www.comparabus.com/fr/
# https://explee.com/fr/
# http://www.tracktl.com/
# https://www.boaterfly.com/
# http://www.etregourmand.com/
# http://www.luckyloc.com/
# https://techtalent.io/
# Unexpected error: HTTPSConnectionPool(host='techtalent.io', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa18e966d8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# http://www.sharingbox.fr/fr
# http://www.co-recyclage.com/
# https://www.verychic.com
# http://www.buzcard.fr/
# http://www.free.fr/adsl/freebox-mini.html
# http://soundsgood.co
# http://www.frenchtech.co/
# http://www.coindusalarie.fr
# http://www.lessuricates.fr
# http://bit.ly/1F139EQ
# http://www.izneo.com/
# http://dealerdecoque.fr/fr/
# http://www.finansemble.fr/
# http://www.flashgap.com
# Unexpected error: HTTPSConnectionPool(host='www.flashgap.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://overlay.ms/
# http://www.costockage.fr
# http://www.lengow.fr/
# https://www.drivy.com/
# https://www.remaker.fr/
# http://bit.ly/iheartpromo
# https://www.officehour.fr/
# Unexpected error: HTTPSConnectionPool(host='www.officehour.fr', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa196e8710>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# http://www.psa-entreprise.fr/malou-tech/securite.php
# http://www.lecab.fr
# http://www.kiwup.com
# http://www.brocantelab.com
# http://www.streamwide.fr/produits-solutions/portfolio/joignabilit%C3%A9/my-social-line
# Unexpected error: HTTPSConnectionPool(host='www.streamwide.com', port=443): Max retries exceeded with url: /produits-solutions/portfolio/joignabilit%c3%a9/my-social-line (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.oledcomm.com/
# https://www.lapetitetranche.fr/
# Unexpected error: HTTPSConnectionPool(host='www.lapetitetranche.fr', port=443): Max retries exceeded with url: / (Caused by SSLError(CertificateError("hostname 'www.lapetitetranche.fr' doesn't match either of 'registry.4x.fr', 'www.registry.4x.fr'",),))
# http://www.tellmeplus.com/
# http://www.mamanlou.com/
# http://sketchfab.com
# https://www.let-it-bill.com/fr/accueil/
# http://www.3dswipe.com/
# https://www.netatmo.com/fr-FR/produit/thermostat
# http://www.dataiku.com/
# http://www.woozgo.fr/
# http://www.coop-time.fr/
# http://www.swingli.com/
# http://www.pilipop.com/
# http://jammies.fr/
# http://www.clicrdv.com/fr/
# http://www.powize.com/fr/
# https://sowefund.com/
# https://www.onecub.com/
# https://toktoktok.com/
# Unexpected error: HTTPSConnectionPool(host='toktoktok.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a63ddd8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://bienvenue.sellsy.com/
# https://www.daycause.com
# Unexpected error: HTTPSConnectionPool(host='www.daycause.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a01e3c8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# https://www.juliedesk.com/fr
# http://www.accengage.com/
# https://www.nirror.com/fr/
# Unexpected error: HTTPSConnectionPool(host='www.nirror.com', port=443): Max retries exceeded with url: /fr/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa1a7a8d68>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# https://www.fizzer.io/
# http://www.ilove.fr/
# https://www.buuyers.com
# http://www.urbanhello.com/fr/
# http://www.paris-cilasortiedumetro.fr/
# http://beta.vizir.co/
# Unexpected error: HTTPConnectionPool(host='beta.vizir.co', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19f032b0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.fieldin.com
# http://portrait2point0.com
# http://fr.umanlife.com/
# Unexpected error: HTTPConnectionPool(host='fr.umanlife.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19d55438>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://pretapousser.fr/
# http://www.sant.ee/
# Unexpected error: HTTPConnectionPool(host='www.sant.ee', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19d62860>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://laboxculturelle.com/
# Unexpected error: HTTPSConnectionPool(host='laboxculturelle.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faa19d62630>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://trampolinn.com/fr/
# http://www.goku.fr/
# http://www.yonder.fr/
# http://www.zenpark.com/
# http://www.mabrosseatemps.com
# http://seeqle.com/
# http://www.hopways.com
# Unexpected error: HTTPSConnectionPool(host='www.hopways.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://www.getkudoz.com/
# https://www.tipeee.com/lang/switch/1
# http://sortirtoday.fr/
# Unexpected error: HTTPConnectionPool(host='sortirtoday.fr', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa19f79b38>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.meetmyjob.fr/fr/
# http://www.vallib.com/
# https://www.braineet.com/
# http://www.pour-combien.com/
# http://touscuistots.fr/
# Unexpected error: HTTPConnectionPool(host='touscuistots.fr', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1a93a668>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# https://www.paytop.com/
# https://www.otheatro.com/
# https://hoolders.com/
# Unexpected error: HTTPSConnectionPool(host='hoolders.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# http://jetravailleamondomicile.com/index.html
# http://www.foodette.fr/
# http://onemuze.com/
# Unexpected error: HTTPConnectionPool(host='onemuze.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa1ab77e48>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# https://bankin.com/
# http://www.arbre-a-vent.fr/Arbre-vent_31.html
# http://reassurez-moi.fr/
# http://zenchef.com/fr/
# http://lapausecinema.co/
# Unexpected error: HTTPConnectionPool(host='lapausecinema.co', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faa18b18d68>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# http://www.glowee.fr/
# https://sparingvision.com/en/
# https://www.famileat.fr/
#    Unnamed: 0  ...                                        Description
# 0           0  ...  Votre corps sait ce dont il a besoin. Apprenez...
# 1           1  ...  Télécharge la 1ère app de recrutement de rempl...
# 2           2  ...              Formulaire de recrutement d'interstis
# 3           3  ...  kShuttle.io offre une vision unifiée de l'effi...
# 4           4  ...                                               None
# 5           5  ...  Découvrez Citizenwave, la Plateforme analytiqu...
# 6           6  ...  Agence fondée par une artiste, votre site sera...
# 7           7  ...                                               None
# 8           8  ...  TeamBrain c'est automatiser les réponses ✔️ sa...
# 9           9  ...  Combining the best of data science and luxury ...
#
# [10 rows x 4 columns]

# %%
dataframe.loc
# Out:
#       Unnamed: 0  ...                                        Description
# 0              0  ...  Votre corps sait ce dont il a besoin. Apprenez...
# 1              1  ...  Télécharge la 1ère app de recrutement de rempl...
# 2              2  ...              Formulaire de recrutement d'interstis
# 3              3  ...  kShuttle.io offre une vision unifiée de l'effi...
# 4              4  ...                                               None
# ...          ...  ...                                                ...
# 3882        3885  ...  Cahier de réservation digital pour restaurant,...
# 3883        3886  ...                                               None
# 3884        3887  ...  Glowee est un système de lumière biologique pe...
# 3885        3888  ...  SparingVision is a biotechnology company focus...
# 3886        3889  ...  Vos menus pour la semaine ! Vos plats préférés...
#
# [3887 rows x 4 columns]
